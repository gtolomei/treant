# %% [markdown]
# # Non-Interferent Training

# %% [markdown]
# # Documentation
#
#  - http://lightgbm.readthedocs.io/en/latest/
#  - http://lightgbm.readthedocs.io/en/latest/Python-Intro.html
#  - https://github.com/Microsoft/LightGBM/tree/master/examples/python-guide

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import numpy as np
import pandas as pd
import lightgbm
import pickle
import json
import functools
from os import listdir
from os.path import isfile, join
from nilib import *

# %% [markdown]
# # Path to dataset files

# %%
# DATASET_NAME="census"
# TRAINING_BUDGETS= [5, 15, 150, 300]
# ALPHAS = [0.1, 0.5, 0.9, 1.0]

DATASET_NAME="wine2"
TRAINING_BUDGETS= [20,30,40]
ALPHAS = [0.1, 0.5, 1.0]

# %%
DATASET_DIR="../data/{}".format(DATASET_NAME)
MODELS_DIR="../out/models/{}".format(DATASET_NAME)
TRAINING_FILENAME=DATASET_DIR + "/" + "train_ori.csv.bz2"
TRAINING_FILENAME_ATT=DATASET_DIR + "/" + "train_B{}.csv.bz2"
VALIDATION_FILENAME=DATASET_DIR + "/" + "valid_ori.csv.bz2"
VALIDATION_FILENAME_ATT=DATASET_DIR + "/" + "valid_B{}.csv.bz2"
TEST_FILENAME=DATASET_DIR + "/" + "test_ori.csv.bz2"
TEST_FILENAME_ATT=DATASET_DIR + "/" + "test_B{}.csv.bz2"
MODEL_FILENAME=MODELS_DIR + "/non-interferent_{}_A{}_B{}"

# %% [markdown]
# # Non-Interferent GBDT

# %%
def extend_non_interf_model(atk_train, atk_valid, cat_fx, 
                            alpha=1.0, num_trees=1, params=None):
    ''' 
    model  : is the LightGBM Model
    data   : data matrix with all valid attacks (last column is label)
    returns the new model (is model modified inplace?)
    '''
    
    assert atk_train.shape[1]==atk_valid.shape[1], "Train/Valid Mismatch!"
    
    train_groups = atk_train['instance_id'].value_counts().sort_index().values
    valid_groups = atk_valid['instance_id'].value_counts().sort_index().values

    original_train_ids = np.cumsum(train_groups[:-1])
    original_train_ids = np.insert(original_train_ids, 0, 0)
    
    original_valid_ids = np.cumsum(valid_groups[:-1])
    original_valid_ids = np.insert(original_valid_ids, 0, 0)

    # get index of categorical features 
    cat_fx = np.where(atk_train.columns.isin(cat_fx))[0]
    cat_fx = list([int(x) for x in cat_fx])
    print ("CatFX:", atk_train.columns.values[cat_fx])

    # remove instance id
    atk_train = atk_train.iloc[:,1:].values
    atk_valid = atk_valid.iloc[:,1:].values
    cat_fx = [x - 1 for x in cat_fx]
        
    unatk_train = atk_train[original_train_ids,:]
    unatk_valid = atk_valid[original_valid_ids,:]

    if cat_fx is None or len(cat_fx)==0:
        cat_fx = "auto"

    # -------------------------
    # train first iteration
    lgbm_train = lightgbm.Dataset(data=unatk_train[:,:-1], 
                                  label=unatk_train[:,-1],
                                  categorical_feature = cat_fx)
    
    lgbm_valid = lightgbm.Dataset(data=atk_valid[:,:-1], 
                                  label=atk_valid[:,-1],
                                  group=valid_groups,
                                  categorical_feature = cat_fx)

    lgbm_info = {}
    lgbm_model = lightgbm.train(params, lgbm_train, 
                                num_boost_round = 1,
                                fobj  = optimize_log_loss, 
                                feval = functools.partial(avg_non_interferent_log_loss, alpha=alpha), #avg_log_loss
                                evals_result = lgbm_info,
                                valid_sets   = [lgbm_valid], 
                                valid_names  = ['valid'],
                                verbose_eval=25)

    # -------------------------
    # train other iteration
    def get_ni_w_old(preds, labels, groups):
        # "weights"
        w = np.ones(len(groups))

        offset = 0
        for instance_id, g in enumerate(groups):
            exp_pl = np.exp(- preds[offset:offset+g] * labels[offset:offset+g])
            w[instance_id] = 1.0 / np.max(1.0 + exp_pl)
            offset += g  

        return w
    
    def get_ni_w(preds, labels, groups):
        # "weights"
        w = np.ones(len(groups))

        offset = 0
        for instance_id, g in enumerate(groups):
            exp_pl = np.exp(- preds[offset:offset+g] * labels[offset:offset+g])
            # can we replace with e^max
            w[instance_id] = 1.0 / np.max(1.0 + exp_pl)
            offset += g  

        return w
    
    def get_ni_w_num(preds, labels, groups):
        # "weights"
        w = np.ones(len(groups))

        offset = 0
        for instance_id, g in enumerate(groups):
            exp_pl = np.exp(- preds[offset:offset+g] * labels[offset:offset+g])
            w[instance_id] = 1.0 / np.sum(1.0 + exp_pl)
            w[instance_id] *= np.exp(-2.0) 
            offset += g  

        return w

    for t in range (1, num_trees):
    
        # get predictions on atk instances
        train_preds  = lgbm_model.predict(atk_train[:,:-1])
        train_labels = atk_train[:,-1]
        train_weights = get_ni_w(train_preds, train_labels, train_groups)
                
        # repeat for validation
        valid_preds  = lgbm_model.predict(atk_valid[:,:-1])
        valid_labels = atk_valid[:,-1]
        valid_weights = get_ni_w(valid_preds, valid_labels, valid_groups)
        
        # prepare data and train
        lgbm_train = lightgbm.Dataset(data=unatk_train[:,:-1], 
                                      label=unatk_train[:,-1],
                                      weight=train_weights,
                                      categorical_feature = cat_fx)

        lgbm_valid = lightgbm.Dataset(data=atk_valid[:,:-1], 
                                      label=atk_valid[:,-1],
                                      group=valid_groups,
                                      categorical_feature = cat_fx)

        new_lgbm_info = {}
        lgbm_model = lightgbm.train(params, lgbm_train, 
                                    num_boost_round = 1, 
                                    init_model = lgbm_model,
                                    fobj  = functools.partial(optimize_non_interferent_log_loss, alpha=alpha), 
                                    feval = functools.partial(avg_non_interferent_log_loss, alpha=alpha), #avg_log_loss
                                    evals_result = new_lgbm_info,
                                    valid_sets   = [lgbm_valid], #[lgbm_train, lgbm_valid], 
                                    valid_names  = ['valid'],    #['train', 'valid'],
                                    verbose_eval=25)
        
        awesome_hack = 'avg_non_interferent_log_loss [alpha={:.2f}]'.format(alpha)
        lgbm_info['valid'][awesome_hack] += new_lgbm_info['valid'][awesome_hack]


    return lgbm_model, lgbm_info

# %%
def train_non_interferent(train_file, valid_file, test_file, output_model_file, alpha=1.0):
    exp = pd.DataFrame(columns=['num_trees', 'learning_rate', 'num_leaves', 'alpha', 'best_round', 'metric', 'filename'])
    
    # load train/valid/test
    atk_train, atk_valid, atk_test, cat_fx = load_atk_train_valid_test(train_file, valid_file, test_file)
    
    for num_trees in [500]:
        best_model = None
        best_info = None
        best_loss = np.inf
        awesome_hack = 'avg_non_interferent_log_loss [alpha={:.2f}]'.format(alpha)

        for learning_rate in [0.05]:
            for num_leaves in [24]:

                lgbm_params = { 'learning_rate': learning_rate, 
                                'num_leaves': num_leaves} 
                lgbm_model, lgbm_info = extend_non_interf_model(atk_train, atk_valid, cat_fx, 
                            alpha=alpha, num_trees=num_trees, params=lgbm_params)

                # save file
                best_valid_iter = np.argmin(lgbm_info['valid'][awesome_hack])

                model_file_name = "{:s}_T{:d}_S{:04d}_L{:d}_A{:03d}_R{:d}.model".format(output_model_file,
                                                                                    num_trees,
                                                                                    int(learning_rate*1000),
                                                                                    num_leaves,
                                                                                    int(alpha * 100),
                                                                                    best_valid_iter + 1
                                                                                   )
                # update experimental results
                exp = exp.append({'num_trees': num_trees, 
                              'learning_rate':learning_rate,
                              'num_leaves':num_leaves, 
                              'alpha': alpha,
                              'best_round':best_valid_iter+1, 
                              'metric':lgbm_info['valid'][awesome_hack][best_valid_iter],
                              'filename':model_file_name},
                             ignore_index=True)




                lgbm_model.save_model(model_file_name)
                print ("Model saved to", model_file_name)
                    
    return exp

# %%
for B in TRAINING_BUDGETS:
        for A in ALPHAS:
            experiments = train_non_interferent(TRAINING_FILENAME_ATT.format(B),
                                                VALIDATION_FILENAME_ATT.format(B),
                                                TEST_FILENAME_ATT.format(B),
                                                MODEL_FILENAME.format(DATASET_NAME, int(A*100), B),
                                                alpha=A)  

            experiments.to_csv(MODEL_FILENAME.format(DATASET_NAME, int(A*100), B) + ".csv", index=False)

            print(experiments)
            print ('best model is:', experiments.sort_values('metric').iloc[0]['filename'] )
# Out:
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.528235
# [50]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.488898
# [75]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.474651
# [100]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.46614
# [125]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.462915
# [150]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.457716
# [175]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455223
# [200]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455095
# [225]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.453322
# [250]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454221
# [275]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455473
# [300]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455454
# [325]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455673
# [350]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.456122
# [375]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455245
# [400]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455996
# [425]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.456114
# [450]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.457855
# [475]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.459983
# [500]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.461261
# Model saved to ../out/models/wine2/non-interferent_wine2_A10_B20_T500_S0050_L24_A010_R233.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    0.1        233  0.453078
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A10_...
# best model is: ../out/models/wine2/non-interferent_wine2_A10_B20_T500_S0050_L24_A010_R233.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.562176
# [50]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.532306
# [75]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.51992
# [100]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.516195
# [125]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.514167
# [150]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.512899
# [175]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.511291
# [200]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.511965
# [225]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.512601
# [250]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.513202
# [275]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.513167
# [300]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.515267
# [325]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.516041
# [350]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.517964
# [375]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.521369
# [400]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.522537
# [425]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.526224
# [450]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.529611
# [475]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.530823
# [500]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.533324
# Model saved to ../out/models/wine2/non-interferent_wine2_A50_B20_T500_S0050_L24_A050_R185.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    0.5        185  0.510928
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A50_...
# best model is: ../out/models/wine2/non-interferent_wine2_A50_B20_T500_S0050_L24_A050_R185.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.592898
# [50]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.569887
# [75]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.562128
# [100]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.559326
# [125]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.560735
# [150]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.559699
# [175]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.559831
# [200]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.559381
# [225]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.56197
# [250]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.563986
# [275]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.566979
# [300]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.57126
# [325]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.574624
# [350]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.576362
# [375]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.582318
# [400]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.586366
# [425]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.591013
# [450]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.596892
# [475]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.605392
# [500]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.610983
# Model saved to ../out/models/wine2/non-interferent_wine2_A100_B20_T500_S0050_L24_A100_R143.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    1.0        143  0.558306
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A100...
# best model is: ../out/models/wine2/non-interferent_wine2_A100_B20_T500_S0050_L24_A100_R143.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.527806
# [50]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.489194
# [75]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.47419
# [100]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.469161
# [125]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.46457
# [150]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.460954
# [175]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.457982
# [200]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.456051
# [225]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454055
# [250]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454515
# [275]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454561
# [300]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455411
# [325]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455993
# [350]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.457011
# [375]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.458576
# [400]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.459203
# [425]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.461587
# [450]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.461181
# [475]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.463531
# [500]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.46611
# Model saved to ../out/models/wine2/non-interferent_wine2_A10_B30_T500_S0050_L24_A010_R232.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    0.1        232  0.453533
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A10_...
# best model is: ../out/models/wine2/non-interferent_wine2_A10_B30_T500_S0050_L24_A010_R232.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.563466
# [50]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.535235
# [75]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.523137
# [100]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.517988
# [125]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.517034
# [150]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.515433
# [200]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.51268
# [225]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.513601
# [250]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.516274
# [275]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.519386
# [300]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.52078
# [325]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.522645
# [350]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.52514
# [375]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.52856
# [450]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.540084
# [475]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.544178
# [500]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.547248
# Model saved to ../out/models/wine2/non-interferent_wine2_A50_B30_T500_S0050_L24_A050_R206.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    0.5        206  0.512289
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A50_...
# best model is: ../out/models/wine2/non-interferent_wine2_A50_B30_T500_S0050_L24_A050_R206.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.60023
# [50]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.583617
# [75]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.573218
# [100]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.572307
# [125]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.572236
# [150]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.576091
# [175]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.577996
# [200]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.581745
# [225]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.590333
# [250]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.592512
# [275]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.601268
# [300]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.603472
# [325]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.603248
# [350]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.605738
# [375]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.608567
# [400]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.611379
# [425]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.615963
# [450]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.619853
# [475]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.6254
# [500]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.629841
# Model saved to ../out/models/wine2/non-interferent_wine2_A100_B30_T500_S0050_L24_A100_R106.model
#   num_trees  learning_rate num_leaves  alpha best_round   metric  \
# 0       500           0.05         24    1.0        106  0.57082
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A100...
# best model is: ../out/models/wine2/non-interferent_wine2_A100_B30_T500_S0050_L24_A100_R106.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.527932
# [50]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.488908
# [75]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.472751
# [100]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.46366
# [125]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.46049
# [150]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.457215
# [175]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454325
# [200]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.45388
# [225]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454114
# [250]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.454043
# [275]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.453533
# [300]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.45477
# [325]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455794
# [350]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.456109
# [375]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.455968
# [400]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.456821
# [425]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.458453
# [450]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.459885
# [475]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.462628
# [500]	valid's avg_non_interferent_log_loss [alpha=0.10]: 0.464711
# Model saved to ../out/models/wine2/non-interferent_wine2_A10_B40_T500_S0050_L24_A010_R205.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    0.1        205  0.453443
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A10_...
# best model is: ../out/models/wine2/non-interferent_wine2_A10_B40_T500_S0050_L24_A010_R205.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.56542
# [50]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.537936
# [75]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.526748
# [100]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.522538
# [125]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.519531
# [150]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.519035
# [175]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.519154
# [200]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.520008
# [225]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.522377
# [250]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.525772
# [275]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.526679
# [300]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.532042
# [325]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.535153
# [350]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.538717
# [375]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.541172
# [400]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.542188
# [425]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.545964
# [450]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.548183
# [475]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.550197
# [500]	valid's avg_non_interferent_log_loss [alpha=0.50]: 0.555075
# Model saved to ../out/models/wine2/non-interferent_wine2_A50_B40_T500_S0050_L24_A050_R140.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    0.5        140  0.518154
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A50_...
# best model is: ../out/models/wine2/non-interferent_wine2_A50_B40_T500_S0050_L24_A050_R140.model
# Loading pre-processed files...
# CatFX: []
# [25]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.60213
# [50]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.587346
# [75]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.579941
# [100]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.574947
# [125]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.574853
# [150]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.578249
# [175]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.582057
# [200]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.584114
# [225]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.586267
# [250]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.588826
# [275]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.59437
# [300]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.596157
# [325]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.601882
# [350]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.60845
# [375]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.613279
# [400]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.619773
# [425]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.623003
# [450]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.628305
# [475]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.631638
# [500]	valid's avg_non_interferent_log_loss [alpha=1.00]: 0.637902
# Model saved to ../out/models/wine2/non-interferent_wine2_A100_B40_T500_S0050_L24_A100_R107.model
#   num_trees  learning_rate num_leaves  alpha best_round    metric  \
# 0       500           0.05         24    1.0        107  0.572119
#
#                                             filename
# 0  ../out/models/wine2/non-interferent_wine2_A100...
# best model is: ../out/models/wine2/non-interferent_wine2_A100_B40_T500_S0050_L24_A100_R107.model
