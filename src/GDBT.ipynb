# %% [markdown]
# # Training Models
#
# This notebook contains the code used for training the following learning models:
#
# -  **Standard GBDT** (_baseline 1_)
# -  **Adversarial Boosting** (_baseline 2_)
# -  **Non-Interferent GBDT** (our proposal)

# %% [markdown]
# # Documentation
#
#  - http://lightgbm.readthedocs.io/en/latest/
#  - http://lightgbm.readthedocs.io/en/latest/Python-Intro.html
#  - https://github.com/Microsoft/LightGBM/tree/master/examples/python-guide

# %%
import sys
import os
import numpy as np
import pandas as pd
import lightgbm
import pickle
import json
import functools
from os import listdir
from os.path import isfile, join
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# %% [markdown]
# # Data Preparation

# %%
def label_encode(dataset, categorical_features):
    dataset_le = dataset.copy()
    for column in dataset_le.columns:
        if column in categorical_features:
            dataset_le[column] = dataset_le[column].astype('category')
            dataset_le[column] = dataset_le[column].cat.codes.astype(np.int32)
    return dataset_le

def load_atk_train_valid_test(atk_train_file, atk_valid_file, atk_test_file, 
                              train_split=0.6, valid_split=0.2, force=False):
    
    
    if  (force or 
          not os.path.exists(atk_train_file+".cat.bz2") or
          not os.path.exists(atk_valid_file+".cat.bz2") or
          not os.path.exists(atk_test_file+".cat.bz2") or 
          not os.path.exists(atk_train_file+".cat.json") ):
    
        print ("Pre-processing original files...")

        print ("Loading:", atk_train_file)
        print ("Loading:", atk_valid_file)
        print ("Loading:", atk_test_file)

        train = pd.read_csv(atk_train_file)
        valid = pd.read_csv(atk_valid_file)
        test  = pd.read_csv(atk_test_file)
        
        print ("Train/Valid/Test sizes:", train.shape, valid.shape, test.shape)
        print ("Train/Valid/Test split: {:.2f} {:.2f} {:.2f}"
                   .format( train.shape[0]/(train.shape[0]+valid.shape[0]+test.shape[0]),
                            valid.shape[0]/(train.shape[0]+valid.shape[0]+test.shape[0]),
                            test.shape[0] /(train.shape[0]+valid.shape[0]+test.shape[0]) ) )


        # split-back into train valid test
        if 'instance_id' in train.columns.values:
            print ('   ... with instance ids')
            valid['instance_id'] += train.iloc[-1,0]
            test['instance_id']  += valid.iloc[-1,0]
            assert max(train['instance_id'])<min(valid['instance_id']), "Instance ID mismatch"
            assert max(valid['instance_id'])<min(test['instance_id']), "Instance ID mismatch"
            
            groups = np.concatenate( [ train['instance_id'].value_counts().sort_index().values,
                                       valid['instance_id'].value_counts().sort_index().values,
                                       test['instance_id'].value_counts().sort_index().values ] )
            
            num_train_groups = int( len(groups)*train_split )
            train_size = sum(groups[:num_train_groups])
            num_valid_groups = int( len(groups)*valid_split )
            valid_size = sum(groups[num_train_groups:num_train_groups+num_valid_groups])
        else:
            full_size = len(train) + len(valid) + len(test)
            train_size = int( full_size*train_split )
            valid_size = int( full_size*valid_split )
        
        # concat to process correctly label encoding
        full = pd.concat( [train, valid, test] )

        # get index of categorical features (-1 because of instance_id)
        cat_fx = full.columns.values[np.where(full.dtypes=='object')[0]]
        cat_fx = list(cat_fx)    
        full = label_encode(full, cat_fx)
        with open(atk_train_file+".cat.json", 'w') as fp:
            json.dump(cat_fx, fp)
        print ("CatFX:", cat_fx)

        train_cat = full.iloc[0:train_size,:]
        valid_cat = full.iloc[train_size:train_size+valid_size,:]
        test_cat  = full.iloc[train_size+valid_size:,:]
        
        assert len(train_cat)+len(valid_cat)+len(test_cat)==len(full), "Split sizes mismatch"
        

        print ("Train/Valid/Test sizes:", train_cat.shape, valid_cat.shape, test_cat.shape)
        print ("Train/Valid/Test split: {:.2f} {:.2f} {:.2f}"
                   .format( train_cat.shape[0]/(train_cat.shape[0]+valid_cat.shape[0]+test_cat.shape[0]),
                            valid_cat.shape[0]/(train_cat.shape[0]+valid_cat.shape[0]+test_cat.shape[0]),
                            test_cat.shape[0] /(train_cat.shape[0]+valid_cat.shape[0]+test_cat.shape[0]) ) )

        # save to file
        print ("Saving processed files *.cat.bz2")
        train_cat.to_csv(atk_train_file+".cat.bz2", compression="bz2", index=False)
        valid_cat.to_csv(atk_valid_file+".cat.bz2", compression="bz2", index=False)
        test_cat.to_csv (atk_test_file+".cat.bz2",  compression="bz2", index=False)
        
    else:
        print ("Loading pre-processed files...")

        train_cat = pd.read_csv(atk_train_file+".cat.bz2")
        valid_cat = pd.read_csv(atk_valid_file+".cat.bz2")
        test_cat  = pd.read_csv(atk_test_file+".cat.bz2")
        
        with open(atk_train_file+".cat.json", 'r') as fp:
            cat_fx = json.load(fp)
    
    # return data
    return train_cat, valid_cat, test_cat, cat_fx

# %% [markdown]
# # Objective Functions

# %% [markdown]
# ## Standard
#
# The following function, called <code>optimize_log_loss</code>, is the one that should be optimized (i.e., minimized) for learning _standard_ and _baseline_ approaches. More specifically, this is the standard binary log loss which is used to train any _standard_ or _baseline_ model.

# %% [markdown]
# # $L$ = <code>optimize_log_loss</code>
#
# $$
# L = \frac{1}{|\mathcal{D}|} \cdot \sum_{(\mathbf{x},y) \in \mathcal{D}}\ell(h(\mathbf{x}), y)
# $$
#
# where:
#
# $$
# \ell(h(\mathbf{x}), y) = log(1+e^{(-yh(\mathbf{x}))})
# $$

# %%
def optimize_log_loss(preds, train_data):
    labels = train_data.get_label()
    exp_pl = np.exp(preds * labels)
    # http://www.wolframalpha.com/input/?i=differentiate+log(1+%2B+exp(-kx)+)
    grads = -labels / (1.0 +  exp_pl)  
    # http://www.wolframalpha.com/input/?i=d%5E2%2Fdx%5E2+log(1+%2B+exp(-kx)+)
    hess = labels**2 * exp_pl / (1.0 + exp_pl)**2 

    # this is to optimize average logloss
    norm = 1.0/len(preds)
    grads *= norm
    hess *= norm
    
    return grads, hess

# %% [markdown]
# # Evaluation Metrics

# %% [markdown]
# ## Standard
#
# The following function is the one used for evaluating the quality of the learned model (either _standard_, _adversarial-boosting_, or _non-interferent_). This is the standard <code>avg_log_loss</code>.

# %%
def logistic(x):
    return 1.0/(1.0 + np.exp(-x))

# %%
def logit(p):
    return np.log(p/(1-p))

# %% [markdown]
# # <code>avg_log_loss</code>

# %%
# self-defined eval metric
# f(preds: array, train_data: Dataset) -> name: string, value: array, is_higher_better: bool
def avg_log_loss(preds, train_data):
    
    labels = train_data.get_label()
    losses = np.log(1.0 + np.exp(-preds*labels))
    avg_loss = np.mean(losses)
    
    return 'avg_binary_log_loss', avg_loss, False

# %% [markdown]
# # Training Standard GBDT (_baseline 1_)

# %%
def train_gradient_boosting_baseline( train_file, valid_file, test_file,
                                output_model_file):
    
    exp = pd.DataFrame(columns=['num_trees', 'learning_rate', 'num_leaves', 'best_round', 'avg_binary_log_loss'])
    
    # load train/valid/test
    train, valid, test, cat_fx = load_atk_train_valid_test(train_file, valid_file, test_file)
    
    assert "instance_id" not in train.columns.values, "Wrong training set file for GBDT"

    # get index of categorical features 
    cat_fx = np.where(train.columns.isin(cat_fx))[0]
    cat_fx = list([int(x) for x in cat_fx])  
    print ("CatFX:", train.columns.values[cat_fx])
    

    for num_trees in [1000]:
        best_model = None
        best_info = None
        best_loss = np.inf
        for learning_rate in [0.01, 0.05, 0.1]:
            for num_leaves in [8, 16, 24, 32]:
                # datasets
                lgbm_train = lightgbm.Dataset(data=train.iloc[:,:-1].values, 
                                              label=train.iloc[:,-1].values,
                                              categorical_feature = cat_fx)

                lgbm_valid = lightgbm.Dataset(data=valid.iloc[:,:-1].values, 
                                              label=valid.iloc[:,-1].values,
                                              categorical_feature = cat_fx)

                # run train
                lgbm_params = { 'learning_rate': learning_rate, 
                                'num_leaves': num_leaves} 
                lgbm_info = {}
                lgbm_model = lightgbm.train(lgbm_params, lgbm_train, 
                                            num_boost_round = num_trees,
                                            fobj            = optimize_log_loss, 
                                            feval           = avg_log_loss,
                                            evals_result    = lgbm_info,
                                            valid_sets      = [lgbm_train, lgbm_valid], 
                                            valid_names     = ['train', 'valid'],
                                            verbose_eval    = 50)
                
                if np.min(lgbm_info['valid']['avg_binary_log_loss']) < best_loss:
                    best_model = lgbm_model
                    best_info = lgbm_info
                    best_loss = np.min(lgbm_info['valid']['avg_binary_log_loss'])
                    best_info['num_trees'] = num_trees
                    best_info['learning_rate'] = learning_rate
                    best_info['num_leaves'] = num_leaves
                    
                    
                best_valid_iter = np.argmin(lgbm_info['valid']['avg_binary_log_loss'])
                
                # update experimental results
                exp = exp.append({'num_trees': num_trees, 
                                  'learning_rate':learning_rate,
                                  'num_leaves':num_leaves, 
                                  'best_round':best_valid_iter+1, 
                                  'avg_binary_log_loss':lgbm_info['valid']['avg_binary_log_loss'][best_valid_iter]},
                                 ignore_index=True)
                
        
        # save file
        best_valid_iter = np.argmin(best_info['valid']['avg_binary_log_loss'])

        model_file_name = "{:s}_T{:d}_S{:04d}_L{:d}_R{:d}.model".format(output_model_file,
                                                                        best_info['num_trees'],
                                                                        int(best_info['learning_rate']*1000),
                                                                        best_info['num_leaves'],
                                                                        best_valid_iter + 1
                                                                       )
        
        best_model.save_model(model_file_name)
        print ("Model saved to", model_file_name)
        
        best_model = lightgbm.Booster(model_file=model_file_name)
        print ("Check valid score:", avg_log_loss(preds=best_model.predict(valid.iloc[:,:-1].values),
                                                  train_data=lgbm_valid))

    
    return exp

# %%
# enable/disable LGBM Baseline
if True:
    experiments = train_gradient_boosting_baseline("../data/census/train_ori.csv.bz2",
                                                     "../data/census/valid_ori.csv.bz2",
                                                     "../data/census/test_ori.csv.bz2",
                                                     "../out/models/std_gbdt_census")  

    experiments.to_csv('../out/models/std_gbdt_census.csv', index=False)

    print (experiments)
# Out:
# Loading pre-processed files...
# CatFX: ['workclass' 'marital_status' 'occupation' 'relationship' 'race' 'sex'
#  'native_country']
# /home/lucchese/.local/lib/python3.6/site-packages/lightgbm/basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /home/lucchese/.local/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [5]	train's avg_binary_log_loss: 0.669909	valid's avg_binary_log_loss: 0.670078
# [10]	train's avg_binary_log_loss: 0.648818	valid's avg_binary_log_loss: 0.649129
# [15]	train's avg_binary_log_loss: 0.629588	valid's avg_binary_log_loss: 0.630009
# [20]	train's avg_binary_log_loss: 0.611985	valid's avg_binary_log_loss: 0.612517
# [25]	train's avg_binary_log_loss: 0.595845	valid's avg_binary_log_loss: 0.59644
# [30]	train's avg_binary_log_loss: 0.580993	valid's avg_binary_log_loss: 0.581579
# [35]	train's avg_binary_log_loss: 0.567319	valid's avg_binary_log_loss: 0.5679
# [40]	train's avg_binary_log_loss: 0.554711	valid's avg_binary_log_loss: 0.555295
# [45]	train's avg_binary_log_loss: 0.543066	valid's avg_binary_log_loss: 0.54366
# [50]	train's avg_binary_log_loss: 0.532162	valid's avg_binary_log_loss: 0.532738
# [55]	train's avg_binary_log_loss: 0.522024	valid's avg_binary_log_loss: 0.52252
# [60]	train's avg_binary_log_loss: 0.51261	valid's avg_binary_log_loss: 0.513041
# [65]	train's avg_binary_log_loss: 0.503831	valid's avg_binary_log_loss: 0.504231
# [70]	train's avg_binary_log_loss: 0.49565	valid's avg_binary_log_loss: 0.495911
# [75]	train's avg_binary_log_loss: 0.488029	valid's avg_binary_log_loss: 0.488241
# [80]	train's avg_binary_log_loss: 0.480881	valid's avg_binary_log_loss: 0.481055
# [85]	train's avg_binary_log_loss: 0.474249	valid's avg_binary_log_loss: 0.474406
# [90]	train's avg_binary_log_loss: 0.467996	valid's avg_binary_log_loss: 0.468079
# [95]	train's avg_binary_log_loss: 0.462203	valid's avg_binary_log_loss: 0.46215
# [100]	train's avg_binary_log_loss: 0.456843	valid's avg_binary_log_loss: 0.456639
# [105]	train's avg_binary_log_loss: 0.451805	valid's avg_binary_log_loss: 0.451524
# [110]	train's avg_binary_log_loss: 0.447153	valid's avg_binary_log_loss: 0.446731
# [115]	train's avg_binary_log_loss: 0.442751	valid's avg_binary_log_loss: 0.442272
# [120]	train's avg_binary_log_loss: 0.438642	valid's avg_binary_log_loss: 0.438092
# [125]	train's avg_binary_log_loss: 0.434805	valid's avg_binary_log_loss: 0.434195
# [130]	train's avg_binary_log_loss: 0.431142	valid's avg_binary_log_loss: 0.430453
# [135]	train's avg_binary_log_loss: 0.42779	valid's avg_binary_log_loss: 0.427054
# [140]	train's avg_binary_log_loss: 0.424524	valid's avg_binary_log_loss: 0.423723
# [145]	train's avg_binary_log_loss: 0.421406	valid's avg_binary_log_loss: 0.420557
# [150]	train's avg_binary_log_loss: 0.418456	valid's avg_binary_log_loss: 0.417582
# [155]	train's avg_binary_log_loss: 0.415706	valid's avg_binary_log_loss: 0.414795
# [160]	train's avg_binary_log_loss: 0.413092	valid's avg_binary_log_loss: 0.412148
# [165]	train's avg_binary_log_loss: 0.410583	valid's avg_binary_log_loss: 0.409628
# [170]	train's avg_binary_log_loss: 0.408228	valid's avg_binary_log_loss: 0.407278
# [175]	train's avg_binary_log_loss: 0.406035	valid's avg_binary_log_loss: 0.405084
# [180]	train's avg_binary_log_loss: 0.403878	valid's avg_binary_log_loss: 0.402914
# [185]	train's avg_binary_log_loss: 0.401807	valid's avg_binary_log_loss: 0.40079
# [190]	train's avg_binary_log_loss: 0.399886	valid's avg_binary_log_loss: 0.398869
# [195]	train's avg_binary_log_loss: 0.398053	valid's avg_binary_log_loss: 0.397028
# [200]	train's avg_binary_log_loss: 0.396337	valid's avg_binary_log_loss: 0.395321
# [205]	train's avg_binary_log_loss: 0.394752	valid's avg_binary_log_loss: 0.393708
# [210]	train's avg_binary_log_loss: 0.393071	valid's avg_binary_log_loss: 0.392031
# [215]	train's avg_binary_log_loss: 0.391632	valid's avg_binary_log_loss: 0.390598
# [220]	train's avg_binary_log_loss: 0.390247	valid's avg_binary_log_loss: 0.389204
# [225]	train's avg_binary_log_loss: 0.388783	valid's avg_binary_log_loss: 0.387751
# [230]	train's avg_binary_log_loss: 0.387555	valid's avg_binary_log_loss: 0.386535
# [235]	train's avg_binary_log_loss: 0.386325	valid's avg_binary_log_loss: 0.385291
# [240]	train's avg_binary_log_loss: 0.385169	valid's avg_binary_log_loss: 0.384111
# [245]	train's avg_binary_log_loss: 0.383916	valid's avg_binary_log_loss: 0.382836
# [250]	train's avg_binary_log_loss: 0.382769	valid's avg_binary_log_loss: 0.381695
# [255]	train's avg_binary_log_loss: 0.381754	valid's avg_binary_log_loss: 0.380688
# [260]	train's avg_binary_log_loss: 0.380793	valid's avg_binary_log_loss: 0.379773
# [265]	train's avg_binary_log_loss: 0.37986	valid's avg_binary_log_loss: 0.378855
# [270]	train's avg_binary_log_loss: 0.378967	valid's avg_binary_log_loss: 0.377975
# [275]	train's avg_binary_log_loss: 0.378045	valid's avg_binary_log_loss: 0.37706
# [280]	train's avg_binary_log_loss: 0.377257	valid's avg_binary_log_loss: 0.376321
# [285]	train's avg_binary_log_loss: 0.376489	valid's avg_binary_log_loss: 0.375589
# [290]	train's avg_binary_log_loss: 0.375729	valid's avg_binary_log_loss: 0.374857
# [295]	train's avg_binary_log_loss: 0.375015	valid's avg_binary_log_loss: 0.374153
# [300]	train's avg_binary_log_loss: 0.374303	valid's avg_binary_log_loss: 0.373482
# [305]	train's avg_binary_log_loss: 0.373603	valid's avg_binary_log_loss: 0.372827
# [310]	train's avg_binary_log_loss: 0.372987	valid's avg_binary_log_loss: 0.37224
# [315]	train's avg_binary_log_loss: 0.372359	valid's avg_binary_log_loss: 0.371608
# [320]	train's avg_binary_log_loss: 0.371821	valid's avg_binary_log_loss: 0.371127
# [325]	train's avg_binary_log_loss: 0.371275	valid's avg_binary_log_loss: 0.370613
# [330]	train's avg_binary_log_loss: 0.370707	valid's avg_binary_log_loss: 0.370084
# [335]	train's avg_binary_log_loss: 0.37019	valid's avg_binary_log_loss: 0.369584
# [340]	train's avg_binary_log_loss: 0.369698	valid's avg_binary_log_loss: 0.36912
# [345]	train's avg_binary_log_loss: 0.369176	valid's avg_binary_log_loss: 0.368615
# [350]	train's avg_binary_log_loss: 0.368703	valid's avg_binary_log_loss: 0.368158
# [355]	train's avg_binary_log_loss: 0.368245	valid's avg_binary_log_loss: 0.367697
# [360]	train's avg_binary_log_loss: 0.367807	valid's avg_binary_log_loss: 0.367283
# [365]	train's avg_binary_log_loss: 0.367318	valid's avg_binary_log_loss: 0.366813
# [370]	train's avg_binary_log_loss: 0.366798	valid's avg_binary_log_loss: 0.366301
# [375]	train's avg_binary_log_loss: 0.366362	valid's avg_binary_log_loss: 0.365872
# [380]	train's avg_binary_log_loss: 0.365936	valid's avg_binary_log_loss: 0.365471
# [385]	train's avg_binary_log_loss: 0.365527	valid's avg_binary_log_loss: 0.365076
# [390]	train's avg_binary_log_loss: 0.365132	valid's avg_binary_log_loss: 0.364709
# [395]	train's avg_binary_log_loss: 0.364778	valid's avg_binary_log_loss: 0.364374
# [400]	train's avg_binary_log_loss: 0.364386	valid's avg_binary_log_loss: 0.363994
# [405]	train's avg_binary_log_loss: 0.364052	valid's avg_binary_log_loss: 0.363693
# [410]	train's avg_binary_log_loss: 0.363717	valid's avg_binary_log_loss: 0.363369
# [415]	train's avg_binary_log_loss: 0.363389	valid's avg_binary_log_loss: 0.363059
# [420]	train's avg_binary_log_loss: 0.363048	valid's avg_binary_log_loss: 0.362733
# [425]	train's avg_binary_log_loss: 0.362728	valid's avg_binary_log_loss: 0.362417
# [430]	train's avg_binary_log_loss: 0.362432	valid's avg_binary_log_loss: 0.362139
# [435]	train's avg_binary_log_loss: 0.362149	valid's avg_binary_log_loss: 0.361873
# [440]	train's avg_binary_log_loss: 0.361843	valid's avg_binary_log_loss: 0.361571
# [445]	train's avg_binary_log_loss: 0.361581	valid's avg_binary_log_loss: 0.361336
# [450]	train's avg_binary_log_loss: 0.361326	valid's avg_binary_log_loss: 0.361101
# [455]	train's avg_binary_log_loss: 0.361074	valid's avg_binary_log_loss: 0.360852
# [460]	train's avg_binary_log_loss: 0.360838	valid's avg_binary_log_loss: 0.36064
# [465]	train's avg_binary_log_loss: 0.360621	valid's avg_binary_log_loss: 0.360462
# [470]	train's avg_binary_log_loss: 0.360366	valid's avg_binary_log_loss: 0.360229
# [475]	train's avg_binary_log_loss: 0.360114	valid's avg_binary_log_loss: 0.359993
# [480]	train's avg_binary_log_loss: 0.359851	valid's avg_binary_log_loss: 0.359756
# [485]	train's avg_binary_log_loss: 0.359611	valid's avg_binary_log_loss: 0.35956
# [490]	train's avg_binary_log_loss: 0.35938	valid's avg_binary_log_loss: 0.359364
# [495]	train's avg_binary_log_loss: 0.359166	valid's avg_binary_log_loss: 0.359169
# [500]	train's avg_binary_log_loss: 0.358943	valid's avg_binary_log_loss: 0.358958
# [505]	train's avg_binary_log_loss: 0.358712	valid's avg_binary_log_loss: 0.358742
# [510]	train's avg_binary_log_loss: 0.358504	valid's avg_binary_log_loss: 0.358552
# [515]	train's avg_binary_log_loss: 0.358298	valid's avg_binary_log_loss: 0.35836
# [520]	train's avg_binary_log_loss: 0.358103	valid's avg_binary_log_loss: 0.358191
# [525]	train's avg_binary_log_loss: 0.357919	valid's avg_binary_log_loss: 0.358036
# [530]	train's avg_binary_log_loss: 0.357724	valid's avg_binary_log_loss: 0.357877
# [535]	train's avg_binary_log_loss: 0.357482	valid's avg_binary_log_loss: 0.357634
# [540]	train's avg_binary_log_loss: 0.35728	valid's avg_binary_log_loss: 0.357434
# [545]	train's avg_binary_log_loss: 0.357055	valid's avg_binary_log_loss: 0.357209
# [550]	train's avg_binary_log_loss: 0.356865	valid's avg_binary_log_loss: 0.357027
# [555]	train's avg_binary_log_loss: 0.356637	valid's avg_binary_log_loss: 0.356794
# [560]	train's avg_binary_log_loss: 0.35645	valid's avg_binary_log_loss: 0.356618
# [565]	train's avg_binary_log_loss: 0.355358	valid's avg_binary_log_loss: 0.355598
# [570]	train's avg_binary_log_loss: 0.353476	valid's avg_binary_log_loss: 0.353847
# [575]	train's avg_binary_log_loss: 0.352452	valid's avg_binary_log_loss: 0.352882
# [580]	train's avg_binary_log_loss: 0.350685	valid's avg_binary_log_loss: 0.351218
# [585]	train's avg_binary_log_loss: 0.349751	valid's avg_binary_log_loss: 0.350331
# [590]	train's avg_binary_log_loss: 0.348118	valid's avg_binary_log_loss: 0.348801
# [595]	train's avg_binary_log_loss: 0.34727	valid's avg_binary_log_loss: 0.348017
# [600]	train's avg_binary_log_loss: 0.345763	valid's avg_binary_log_loss: 0.346611
# [605]	train's avg_binary_log_loss: 0.344947	valid's avg_binary_log_loss: 0.345837
# [610]	train's avg_binary_log_loss: 0.342922	valid's avg_binary_log_loss: 0.343936
# [615]	train's avg_binary_log_loss: 0.34158	valid's avg_binary_log_loss: 0.342671
# [620]	train's avg_binary_log_loss: 0.340867	valid's avg_binary_log_loss: 0.342021
# [625]	train's avg_binary_log_loss: 0.339604	valid's avg_binary_log_loss: 0.340839
# [630]	train's avg_binary_log_loss: 0.338908	valid's avg_binary_log_loss: 0.340193
# [635]	train's avg_binary_log_loss: 0.337723	valid's avg_binary_log_loss: 0.339064
# [640]	train's avg_binary_log_loss: 0.337605	valid's avg_binary_log_loss: 0.338966
# [645]	train's avg_binary_log_loss: 0.336468	valid's avg_binary_log_loss: 0.337905
# [650]	train's avg_binary_log_loss: 0.335842	valid's avg_binary_log_loss: 0.337336
# [655]	train's avg_binary_log_loss: 0.335246	valid's avg_binary_log_loss: 0.33679
# [660]	train's avg_binary_log_loss: 0.334634	valid's avg_binary_log_loss: 0.336225
# [665]	train's avg_binary_log_loss: 0.33361	valid's avg_binary_log_loss: 0.33528
# [670]	train's avg_binary_log_loss: 0.33305	valid's avg_binary_log_loss: 0.334774
# [675]	train's avg_binary_log_loss: 0.33251	valid's avg_binary_log_loss: 0.334269
# [680]	train's avg_binary_log_loss: 0.331565	valid's avg_binary_log_loss: 0.333395
# [685]	train's avg_binary_log_loss: 0.331057	valid's avg_binary_log_loss: 0.332934
# [690]	train's avg_binary_log_loss: 0.330541	valid's avg_binary_log_loss: 0.332469
# [695]	train's avg_binary_log_loss: 0.32965	valid's avg_binary_log_loss: 0.331671
# [700]	train's avg_binary_log_loss: 0.329139	valid's avg_binary_log_loss: 0.331199
# [705]	train's avg_binary_log_loss: 0.328634	valid's avg_binary_log_loss: 0.330729
# [710]	train's avg_binary_log_loss: 0.328105	valid's avg_binary_log_loss: 0.330228
# [715]	train's avg_binary_log_loss: 0.327629	valid's avg_binary_log_loss: 0.329774
# [720]	train's avg_binary_log_loss: 0.327185	valid's avg_binary_log_loss: 0.32938
# [725]	train's avg_binary_log_loss: 0.326728	valid's avg_binary_log_loss: 0.32895
# [730]	train's avg_binary_log_loss: 0.326606	valid's avg_binary_log_loss: 0.328835
# [735]	train's avg_binary_log_loss: 0.326165	valid's avg_binary_log_loss: 0.328442
# [740]	train's avg_binary_log_loss: 0.325729	valid's avg_binary_log_loss: 0.328034
# [745]	train's avg_binary_log_loss: 0.325307	valid's avg_binary_log_loss: 0.327654
# [750]	train's avg_binary_log_loss: 0.325198	valid's avg_binary_log_loss: 0.327548
# [755]	train's avg_binary_log_loss: 0.324779	valid's avg_binary_log_loss: 0.327175
# [760]	train's avg_binary_log_loss: 0.324684	valid's avg_binary_log_loss: 0.327102
# [765]	train's avg_binary_log_loss: 0.324273	valid's avg_binary_log_loss: 0.326724
# [770]	train's avg_binary_log_loss: 0.323861	valid's avg_binary_log_loss: 0.32634
# [775]	train's avg_binary_log_loss: 0.323748	valid's avg_binary_log_loss: 0.326246
# [780]	train's avg_binary_log_loss: 0.323349	valid's avg_binary_log_loss: 0.325885
# [785]	train's avg_binary_log_loss: 0.322952	valid's avg_binary_log_loss: 0.325516
# [790]	train's avg_binary_log_loss: 0.322572	valid's avg_binary_log_loss: 0.325178
# [795]	train's avg_binary_log_loss: 0.322485	valid's avg_binary_log_loss: 0.325104
# [800]	train's avg_binary_log_loss: 0.322108	valid's avg_binary_log_loss: 0.324763
# [805]	train's avg_binary_log_loss: 0.322024	valid's avg_binary_log_loss: 0.324711
# [810]	train's avg_binary_log_loss: 0.321652	valid's avg_binary_log_loss: 0.324376
# [815]	train's avg_binary_log_loss: 0.321574	valid's avg_binary_log_loss: 0.324324
# [820]	train's avg_binary_log_loss: 0.321219	valid's avg_binary_log_loss: 0.324017
# [825]	train's avg_binary_log_loss: 0.320857	valid's avg_binary_log_loss: 0.323683
# [830]	train's avg_binary_log_loss: 0.320769	valid's avg_binary_log_loss: 0.3236
# [835]	train's avg_binary_log_loss: 0.32043	valid's avg_binary_log_loss: 0.323311
# [840]	train's avg_binary_log_loss: 0.32034	valid's avg_binary_log_loss: 0.323229
# [845]	train's avg_binary_log_loss: 0.319998	valid's avg_binary_log_loss: 0.322916
# [850]	train's avg_binary_log_loss: 0.31991	valid's avg_binary_log_loss: 0.322838
# [855]	train's avg_binary_log_loss: 0.319576	valid's avg_binary_log_loss: 0.322533
# [860]	train's avg_binary_log_loss: 0.3195	valid's avg_binary_log_loss: 0.322485
# [865]	train's avg_binary_log_loss: 0.319165	valid's avg_binary_log_loss: 0.322169
# [870]	train's avg_binary_log_loss: 0.319082	valid's avg_binary_log_loss: 0.322109
# [875]	train's avg_binary_log_loss: 0.318754	valid's avg_binary_log_loss: 0.321806
# [880]	train's avg_binary_log_loss: 0.318671	valid's avg_binary_log_loss: 0.321727
# [885]	train's avg_binary_log_loss: 0.318348	valid's avg_binary_log_loss: 0.321443
# [890]	train's avg_binary_log_loss: 0.318266	valid's avg_binary_log_loss: 0.321371
# [895]	train's avg_binary_log_loss: 0.317948	valid's avg_binary_log_loss: 0.321086
# [900]	train's avg_binary_log_loss: 0.317871	valid's avg_binary_log_loss: 0.321022
# [905]	train's avg_binary_log_loss: 0.317563	valid's avg_binary_log_loss: 0.320736
# [910]	train's avg_binary_log_loss: 0.317487	valid's avg_binary_log_loss: 0.320677
# [915]	train's avg_binary_log_loss: 0.317186	valid's avg_binary_log_loss: 0.320402
# [920]	train's avg_binary_log_loss: 0.317119	valid's avg_binary_log_loss: 0.320363
# [925]	train's avg_binary_log_loss: 0.316812	valid's avg_binary_log_loss: 0.320079
# [930]	train's avg_binary_log_loss: 0.316746	valid's avg_binary_log_loss: 0.320032
# [935]	train's avg_binary_log_loss: 0.316453	valid's avg_binary_log_loss: 0.319776
# [940]	train's avg_binary_log_loss: 0.31639	valid's avg_binary_log_loss: 0.319719
# [945]	train's avg_binary_log_loss: 0.316102	valid's avg_binary_log_loss: 0.319458
# [950]	train's avg_binary_log_loss: 0.316039	valid's avg_binary_log_loss: 0.319415
# [955]	train's avg_binary_log_loss: 0.315757	valid's avg_binary_log_loss: 0.319163
# [960]	train's avg_binary_log_loss: 0.315694	valid's avg_binary_log_loss: 0.319116
# [965]	train's avg_binary_log_loss: 0.315416	valid's avg_binary_log_loss: 0.318876
# [970]	train's avg_binary_log_loss: 0.315353	valid's avg_binary_log_loss: 0.318826
# [975]	train's avg_binary_log_loss: 0.315087	valid's avg_binary_log_loss: 0.318585
# [980]	train's avg_binary_log_loss: 0.314824	valid's avg_binary_log_loss: 0.318353
# [985]	train's avg_binary_log_loss: 0.314766	valid's avg_binary_log_loss: 0.318325
# [990]	train's avg_binary_log_loss: 0.314513	valid's avg_binary_log_loss: 0.318086
# [995]	train's avg_binary_log_loss: 0.314259	valid's avg_binary_log_loss: 0.317866
# [1000]	train's avg_binary_log_loss: 0.314203	valid's avg_binary_log_loss: 0.31783
# [5]	train's avg_binary_log_loss: 0.668548	valid's avg_binary_log_loss: 0.66866
# [10]	train's avg_binary_log_loss: 0.646226	valid's avg_binary_log_loss: 0.646447
# [15]	train's avg_binary_log_loss: 0.625908	valid's avg_binary_log_loss: 0.626224
# [20]	train's avg_binary_log_loss: 0.607369	valid's avg_binary_log_loss: 0.607776
# [25]	train's avg_binary_log_loss: 0.590423	valid's avg_binary_log_loss: 0.590888
# [30]	train's avg_binary_log_loss: 0.57478	valid's avg_binary_log_loss: 0.57532
# [35]	train's avg_binary_log_loss: 0.560308	valid's avg_binary_log_loss: 0.560931
# [40]	train's avg_binary_log_loss: 0.546978	valid's avg_binary_log_loss: 0.54769
# [45]	train's avg_binary_log_loss: 0.534676	valid's avg_binary_log_loss: 0.535443
# [50]	train's avg_binary_log_loss: 0.523237	valid's avg_binary_log_loss: 0.524062
# [55]	train's avg_binary_log_loss: 0.512658	valid's avg_binary_log_loss: 0.513482
# [60]	train's avg_binary_log_loss: 0.502939	valid's avg_binary_log_loss: 0.503755
# [65]	train's avg_binary_log_loss: 0.493872	valid's avg_binary_log_loss: 0.494672
# [70]	train's avg_binary_log_loss: 0.485491	valid's avg_binary_log_loss: 0.486293
# [75]	train's avg_binary_log_loss: 0.477702	valid's avg_binary_log_loss: 0.47848
# [80]	train's avg_binary_log_loss: 0.470375	valid's avg_binary_log_loss: 0.471151
# [85]	train's avg_binary_log_loss: 0.463571	valid's avg_binary_log_loss: 0.464338
# [90]	train's avg_binary_log_loss: 0.457255	valid's avg_binary_log_loss: 0.457968
# [95]	train's avg_binary_log_loss: 0.451342	valid's avg_binary_log_loss: 0.452064
# [100]	train's avg_binary_log_loss: 0.445822	valid's avg_binary_log_loss: 0.446526
# [105]	train's avg_binary_log_loss: 0.440609	valid's avg_binary_log_loss: 0.441312
# [110]	train's avg_binary_log_loss: 0.43572	valid's avg_binary_log_loss: 0.436347
# [115]	train's avg_binary_log_loss: 0.431165	valid's avg_binary_log_loss: 0.431723
# [120]	train's avg_binary_log_loss: 0.426883	valid's avg_binary_log_loss: 0.427404
# [125]	train's avg_binary_log_loss: 0.422869	valid's avg_binary_log_loss: 0.423353
# [130]	train's avg_binary_log_loss: 0.419142	valid's avg_binary_log_loss: 0.419615
# [135]	train's avg_binary_log_loss: 0.415624	valid's avg_binary_log_loss: 0.416082
# [140]	train's avg_binary_log_loss: 0.412328	valid's avg_binary_log_loss: 0.412774
# [145]	train's avg_binary_log_loss: 0.409217	valid's avg_binary_log_loss: 0.409654
# [150]	train's avg_binary_log_loss: 0.406336	valid's avg_binary_log_loss: 0.40679
# [155]	train's avg_binary_log_loss: 0.403602	valid's avg_binary_log_loss: 0.404053
# [160]	train's avg_binary_log_loss: 0.401041	valid's avg_binary_log_loss: 0.4015
# [165]	train's avg_binary_log_loss: 0.398634	valid's avg_binary_log_loss: 0.399083
# [170]	train's avg_binary_log_loss: 0.396402	valid's avg_binary_log_loss: 0.396872
# [175]	train's avg_binary_log_loss: 0.394238	valid's avg_binary_log_loss: 0.394729
# [180]	train's avg_binary_log_loss: 0.392243	valid's avg_binary_log_loss: 0.392786
# [185]	train's avg_binary_log_loss: 0.390364	valid's avg_binary_log_loss: 0.390959
# [190]	train's avg_binary_log_loss: 0.388586	valid's avg_binary_log_loss: 0.389206
# [195]	train's avg_binary_log_loss: 0.386929	valid's avg_binary_log_loss: 0.387572
# [200]	train's avg_binary_log_loss: 0.385353	valid's avg_binary_log_loss: 0.386026
# [205]	train's avg_binary_log_loss: 0.383875	valid's avg_binary_log_loss: 0.384589
# [210]	train's avg_binary_log_loss: 0.38247	valid's avg_binary_log_loss: 0.383206
# [215]	train's avg_binary_log_loss: 0.381087	valid's avg_binary_log_loss: 0.381827
# [220]	train's avg_binary_log_loss: 0.37973	valid's avg_binary_log_loss: 0.380514
# [225]	train's avg_binary_log_loss: 0.378488	valid's avg_binary_log_loss: 0.3793
# [230]	train's avg_binary_log_loss: 0.377252	valid's avg_binary_log_loss: 0.378096
# [235]	train's avg_binary_log_loss: 0.376137	valid's avg_binary_log_loss: 0.377026
# [240]	train's avg_binary_log_loss: 0.375057	valid's avg_binary_log_loss: 0.37598
# [245]	train's avg_binary_log_loss: 0.374047	valid's avg_binary_log_loss: 0.374982
# [250]	train's avg_binary_log_loss: 0.37306	valid's avg_binary_log_loss: 0.37402
# [255]	train's avg_binary_log_loss: 0.372046	valid's avg_binary_log_loss: 0.373036
# [260]	train's avg_binary_log_loss: 0.371164	valid's avg_binary_log_loss: 0.37221
# [265]	train's avg_binary_log_loss: 0.37022	valid's avg_binary_log_loss: 0.371301
# [270]	train's avg_binary_log_loss: 0.369415	valid's avg_binary_log_loss: 0.370537
# [275]	train's avg_binary_log_loss: 0.368588	valid's avg_binary_log_loss: 0.369736
# [280]	train's avg_binary_log_loss: 0.367827	valid's avg_binary_log_loss: 0.369008
# [285]	train's avg_binary_log_loss: 0.367065	valid's avg_binary_log_loss: 0.368282
# [290]	train's avg_binary_log_loss: 0.366321	valid's avg_binary_log_loss: 0.367585
# [295]	train's avg_binary_log_loss: 0.365612	valid's avg_binary_log_loss: 0.366929
# [300]	train's avg_binary_log_loss: 0.364864	valid's avg_binary_log_loss: 0.3662
# [305]	train's avg_binary_log_loss: 0.364199	valid's avg_binary_log_loss: 0.365578
# [310]	train's avg_binary_log_loss: 0.363535	valid's avg_binary_log_loss: 0.364955
# [315]	train's avg_binary_log_loss: 0.362886	valid's avg_binary_log_loss: 0.364319
# [320]	train's avg_binary_log_loss: 0.362308	valid's avg_binary_log_loss: 0.363767
# [325]	train's avg_binary_log_loss: 0.36172	valid's avg_binary_log_loss: 0.363213
# [330]	train's avg_binary_log_loss: 0.361158	valid's avg_binary_log_loss: 0.362659
# [335]	train's avg_binary_log_loss: 0.360597	valid's avg_binary_log_loss: 0.362134
# [340]	train's avg_binary_log_loss: 0.360055	valid's avg_binary_log_loss: 0.36163
# [345]	train's avg_binary_log_loss: 0.359542	valid's avg_binary_log_loss: 0.361175
# [350]	train's avg_binary_log_loss: 0.359071	valid's avg_binary_log_loss: 0.360735
# [355]	train's avg_binary_log_loss: 0.35859	valid's avg_binary_log_loss: 0.360259
# [360]	train's avg_binary_log_loss: 0.358129	valid's avg_binary_log_loss: 0.359797
# [365]	train's avg_binary_log_loss: 0.357724	valid's avg_binary_log_loss: 0.359408
# [370]	train's avg_binary_log_loss: 0.3573	valid's avg_binary_log_loss: 0.359008
# [375]	train's avg_binary_log_loss: 0.35693	valid's avg_binary_log_loss: 0.35867
# [380]	train's avg_binary_log_loss: 0.356574	valid's avg_binary_log_loss: 0.358357
# [385]	train's avg_binary_log_loss: 0.356206	valid's avg_binary_log_loss: 0.358026
# [390]	train's avg_binary_log_loss: 0.355864	valid's avg_binary_log_loss: 0.357739
# [395]	train's avg_binary_log_loss: 0.355537	valid's avg_binary_log_loss: 0.35746
# [400]	train's avg_binary_log_loss: 0.355208	valid's avg_binary_log_loss: 0.357185
# [405]	train's avg_binary_log_loss: 0.354914	valid's avg_binary_log_loss: 0.35696
# [410]	train's avg_binary_log_loss: 0.354618	valid's avg_binary_log_loss: 0.356729
# [415]	train's avg_binary_log_loss: 0.354302	valid's avg_binary_log_loss: 0.356445
# [420]	train's avg_binary_log_loss: 0.353994	valid's avg_binary_log_loss: 0.356191
# [425]	train's avg_binary_log_loss: 0.351964	valid's avg_binary_log_loss: 0.354273
# [430]	train's avg_binary_log_loss: 0.35004	valid's avg_binary_log_loss: 0.352447
# [435]	train's avg_binary_log_loss: 0.349013	valid's avg_binary_log_loss: 0.351493
# [440]	train's avg_binary_log_loss: 0.347994	valid's avg_binary_log_loss: 0.350551
# [445]	train's avg_binary_log_loss: 0.347007	valid's avg_binary_log_loss: 0.349625
# [450]	train's avg_binary_log_loss: 0.345303	valid's avg_binary_log_loss: 0.348058
# [455]	train's avg_binary_log_loss: 0.343681	valid's avg_binary_log_loss: 0.346571
# [460]	train's avg_binary_log_loss: 0.341545	valid's avg_binary_log_loss: 0.344571
# [465]	train's avg_binary_log_loss: 0.340097	valid's avg_binary_log_loss: 0.343257
# [470]	train's avg_binary_log_loss: 0.338687	valid's avg_binary_log_loss: 0.341992
# [475]	train's avg_binary_log_loss: 0.336798	valid's avg_binary_log_loss: 0.340239
# [480]	train's avg_binary_log_loss: 0.335547	valid's avg_binary_log_loss: 0.33912
# [485]	train's avg_binary_log_loss: 0.334826	valid's avg_binary_log_loss: 0.338498
# [490]	train's avg_binary_log_loss: 0.333582	valid's avg_binary_log_loss: 0.337378
# [495]	train's avg_binary_log_loss: 0.332876	valid's avg_binary_log_loss: 0.336749
# [500]	train's avg_binary_log_loss: 0.332215	valid's avg_binary_log_loss: 0.336156
# [505]	train's avg_binary_log_loss: 0.330679	valid's avg_binary_log_loss: 0.334713
# [510]	train's avg_binary_log_loss: 0.329605	valid's avg_binary_log_loss: 0.33373
# [515]	train's avg_binary_log_loss: 0.328591	valid's avg_binary_log_loss: 0.332792
# [520]	train's avg_binary_log_loss: 0.327611	valid's avg_binary_log_loss: 0.331908
# [525]	train's avg_binary_log_loss: 0.327024	valid's avg_binary_log_loss: 0.331402
# [530]	train's avg_binary_log_loss: 0.326837	valid's avg_binary_log_loss: 0.331271
# [535]	train's avg_binary_log_loss: 0.325924	valid's avg_binary_log_loss: 0.330462
# [540]	train's avg_binary_log_loss: 0.325373	valid's avg_binary_log_loss: 0.329978
# [545]	train's avg_binary_log_loss: 0.324854	valid's avg_binary_log_loss: 0.329511
# [550]	train's avg_binary_log_loss: 0.32399	valid's avg_binary_log_loss: 0.328728
# [555]	train's avg_binary_log_loss: 0.323467	valid's avg_binary_log_loss: 0.328284
# [560]	train's avg_binary_log_loss: 0.322962	valid's avg_binary_log_loss: 0.327853
# [565]	train's avg_binary_log_loss: 0.32184	valid's avg_binary_log_loss: 0.32683
# [570]	train's avg_binary_log_loss: 0.321095	valid's avg_binary_log_loss: 0.326201
# [575]	train's avg_binary_log_loss: 0.320654	valid's avg_binary_log_loss: 0.325841
# [580]	train's avg_binary_log_loss: 0.320197	valid's avg_binary_log_loss: 0.325468
# [585]	train's avg_binary_log_loss: 0.31922	valid's avg_binary_log_loss: 0.324608
# [590]	train's avg_binary_log_loss: 0.318798	valid's avg_binary_log_loss: 0.324265
# [595]	train's avg_binary_log_loss: 0.318134	valid's avg_binary_log_loss: 0.323697
# [600]	train's avg_binary_log_loss: 0.31773	valid's avg_binary_log_loss: 0.323377
# [605]	train's avg_binary_log_loss: 0.316847	valid's avg_binary_log_loss: 0.322596
# [610]	train's avg_binary_log_loss: 0.316468	valid's avg_binary_log_loss: 0.32229
# [615]	train's avg_binary_log_loss: 0.316095	valid's avg_binary_log_loss: 0.321991
# [620]	train's avg_binary_log_loss: 0.315491	valid's avg_binary_log_loss: 0.32148
# [625]	train's avg_binary_log_loss: 0.31513	valid's avg_binary_log_loss: 0.321203
# [630]	train's avg_binary_log_loss: 0.314557	valid's avg_binary_log_loss: 0.320694
# [635]	train's avg_binary_log_loss: 0.314002	valid's avg_binary_log_loss: 0.320213
# [640]	train's avg_binary_log_loss: 0.313669	valid's avg_binary_log_loss: 0.319945
# [645]	train's avg_binary_log_loss: 0.313545	valid's avg_binary_log_loss: 0.319869
# [650]	train's avg_binary_log_loss: 0.313024	valid's avg_binary_log_loss: 0.319411
# [655]	train's avg_binary_log_loss: 0.312715	valid's avg_binary_log_loss: 0.319154
# [660]	train's avg_binary_log_loss: 0.3126	valid's avg_binary_log_loss: 0.319085
# [665]	train's avg_binary_log_loss: 0.312106	valid's avg_binary_log_loss: 0.318646
# [670]	train's avg_binary_log_loss: 0.311995	valid's avg_binary_log_loss: 0.318587
# [675]	train's avg_binary_log_loss: 0.311703	valid's avg_binary_log_loss: 0.318354
# [680]	train's avg_binary_log_loss: 0.311408	valid's avg_binary_log_loss: 0.318117
# [685]	train's avg_binary_log_loss: 0.310947	valid's avg_binary_log_loss: 0.317703
# [690]	train's avg_binary_log_loss: 0.310665	valid's avg_binary_log_loss: 0.317476
# [695]	train's avg_binary_log_loss: 0.310223	valid's avg_binary_log_loss: 0.317096
# [700]	train's avg_binary_log_loss: 0.309957	valid's avg_binary_log_loss: 0.316903
# [705]	train's avg_binary_log_loss: 0.309689	valid's avg_binary_log_loss: 0.316683
# [710]	train's avg_binary_log_loss: 0.309424	valid's avg_binary_log_loss: 0.31648
# [715]	train's avg_binary_log_loss: 0.309015	valid's avg_binary_log_loss: 0.316127
# [720]	train's avg_binary_log_loss: 0.30876	valid's avg_binary_log_loss: 0.315928
# [725]	train's avg_binary_log_loss: 0.308515	valid's avg_binary_log_loss: 0.315731
# [730]	train's avg_binary_log_loss: 0.30827	valid's avg_binary_log_loss: 0.315539
# [735]	train's avg_binary_log_loss: 0.30803	valid's avg_binary_log_loss: 0.315354
# [740]	train's avg_binary_log_loss: 0.30779	valid's avg_binary_log_loss: 0.315172
# [745]	train's avg_binary_log_loss: 0.307552	valid's avg_binary_log_loss: 0.31499
# [750]	train's avg_binary_log_loss: 0.307317	valid's avg_binary_log_loss: 0.314814
# [755]	train's avg_binary_log_loss: 0.307089	valid's avg_binary_log_loss: 0.314636
# [760]	train's avg_binary_log_loss: 0.30686	valid's avg_binary_log_loss: 0.314463
# [765]	train's avg_binary_log_loss: 0.306633	valid's avg_binary_log_loss: 0.314306
# [770]	train's avg_binary_log_loss: 0.30654	valid's avg_binary_log_loss: 0.314271
# [775]	train's avg_binary_log_loss: 0.306327	valid's avg_binary_log_loss: 0.314114
# [780]	train's avg_binary_log_loss: 0.306109	valid's avg_binary_log_loss: 0.313962
# [785]	train's avg_binary_log_loss: 0.305781	valid's avg_binary_log_loss: 0.313682
# [790]	train's avg_binary_log_loss: 0.305698	valid's avg_binary_log_loss: 0.313645
# [795]	train's avg_binary_log_loss: 0.305492	valid's avg_binary_log_loss: 0.3135
# [800]	train's avg_binary_log_loss: 0.305193	valid's avg_binary_log_loss: 0.31325
# [805]	train's avg_binary_log_loss: 0.304995	valid's avg_binary_log_loss: 0.313102
# [810]	train's avg_binary_log_loss: 0.304816	valid's avg_binary_log_loss: 0.312957
# [815]	train's avg_binary_log_loss: 0.304525	valid's avg_binary_log_loss: 0.312712
# [820]	train's avg_binary_log_loss: 0.304332	valid's avg_binary_log_loss: 0.31256
# [825]	train's avg_binary_log_loss: 0.304046	valid's avg_binary_log_loss: 0.312321
# [830]	train's avg_binary_log_loss: 0.303962	valid's avg_binary_log_loss: 0.312286
# [835]	train's avg_binary_log_loss: 0.303875	valid's avg_binary_log_loss: 0.31225
# [840]	train's avg_binary_log_loss: 0.303797	valid's avg_binary_log_loss: 0.312228
# [845]	train's avg_binary_log_loss: 0.303717	valid's avg_binary_log_loss: 0.312192
# [850]	train's avg_binary_log_loss: 0.303534	valid's avg_binary_log_loss: 0.312051
# [855]	train's avg_binary_log_loss: 0.303367	valid's avg_binary_log_loss: 0.311929
# [860]	train's avg_binary_log_loss: 0.303096	valid's avg_binary_log_loss: 0.311703
# [865]	train's avg_binary_log_loss: 0.302823	valid's avg_binary_log_loss: 0.311476
# [870]	train's avg_binary_log_loss: 0.30266	valid's avg_binary_log_loss: 0.311345
# [875]	train's avg_binary_log_loss: 0.302482	valid's avg_binary_log_loss: 0.31122
# [880]	train's avg_binary_log_loss: 0.302324	valid's avg_binary_log_loss: 0.311103
# [885]	train's avg_binary_log_loss: 0.302152	valid's avg_binary_log_loss: 0.310965
# [890]	train's avg_binary_log_loss: 0.30182	valid's avg_binary_log_loss: 0.310673
# [895]	train's avg_binary_log_loss: 0.301592	valid's avg_binary_log_loss: 0.310476
# [900]	train's avg_binary_log_loss: 0.301432	valid's avg_binary_log_loss: 0.310355
# [905]	train's avg_binary_log_loss: 0.301194	valid's avg_binary_log_loss: 0.310151
# [910]	train's avg_binary_log_loss: 0.30088	valid's avg_binary_log_loss: 0.309886
# [915]	train's avg_binary_log_loss: 0.300803	valid's avg_binary_log_loss: 0.309863
# [920]	train's avg_binary_log_loss: 0.300649	valid's avg_binary_log_loss: 0.309749
# [925]	train's avg_binary_log_loss: 0.300417	valid's avg_binary_log_loss: 0.30956
# [930]	train's avg_binary_log_loss: 0.300265	valid's avg_binary_log_loss: 0.309442
# [935]	train's avg_binary_log_loss: 0.300034	valid's avg_binary_log_loss: 0.309255
# [940]	train's avg_binary_log_loss: 0.299802	valid's avg_binary_log_loss: 0.309073
# [945]	train's avg_binary_log_loss: 0.299737	valid's avg_binary_log_loss: 0.309048
# [950]	train's avg_binary_log_loss: 0.299443	valid's avg_binary_log_loss: 0.308805
# [955]	train's avg_binary_log_loss: 0.299374	valid's avg_binary_log_loss: 0.308774
# [960]	train's avg_binary_log_loss: 0.299161	valid's avg_binary_log_loss: 0.308607
# [965]	train's avg_binary_log_loss: 0.299004	valid's avg_binary_log_loss: 0.308509
# [970]	train's avg_binary_log_loss: 0.298794	valid's avg_binary_log_loss: 0.308341
# [975]	train's avg_binary_log_loss: 0.29858	valid's avg_binary_log_loss: 0.308174
# [980]	train's avg_binary_log_loss: 0.298511	valid's avg_binary_log_loss: 0.308142
# [985]	train's avg_binary_log_loss: 0.298306	valid's avg_binary_log_loss: 0.307981
# [990]	train's avg_binary_log_loss: 0.298242	valid's avg_binary_log_loss: 0.307965
# [995]	train's avg_binary_log_loss: 0.298034	valid's avg_binary_log_loss: 0.307797
# [1000]	train's avg_binary_log_loss: 0.297893	valid's avg_binary_log_loss: 0.307697
# [5]	train's avg_binary_log_loss: 0.668079	valid's avg_binary_log_loss: 0.668204
# [10]	train's avg_binary_log_loss: 0.645328	valid's avg_binary_log_loss: 0.645566
# [15]	train's avg_binary_log_loss: 0.624621	valid's avg_binary_log_loss: 0.624969
# [20]	train's avg_binary_log_loss: 0.605722	valid's avg_binary_log_loss: 0.606183
# [25]	train's avg_binary_log_loss: 0.58843	valid's avg_binary_log_loss: 0.588995
# [30]	train's avg_binary_log_loss: 0.572409	valid's avg_binary_log_loss: 0.573102
# [35]	train's avg_binary_log_loss: 0.557633	valid's avg_binary_log_loss: 0.558469
# [40]	train's avg_binary_log_loss: 0.544029	valid's avg_binary_log_loss: 0.545009
# [45]	train's avg_binary_log_loss: 0.53152	valid's avg_binary_log_loss: 0.532615
# [50]	train's avg_binary_log_loss: 0.519896	valid's avg_binary_log_loss: 0.521066
# [55]	train's avg_binary_log_loss: 0.509133	valid's avg_binary_log_loss: 0.510391
# [60]	train's avg_binary_log_loss: 0.499195	valid's avg_binary_log_loss: 0.500518
# [65]	train's avg_binary_log_loss: 0.490004	valid's avg_binary_log_loss: 0.491388
# [70]	train's avg_binary_log_loss: 0.481492	valid's avg_binary_log_loss: 0.482869
# [75]	train's avg_binary_log_loss: 0.473549	valid's avg_binary_log_loss: 0.474932
# [80]	train's avg_binary_log_loss: 0.466175	valid's avg_binary_log_loss: 0.467574
# [85]	train's avg_binary_log_loss: 0.459321	valid's avg_binary_log_loss: 0.460729
# [90]	train's avg_binary_log_loss: 0.452956	valid's avg_binary_log_loss: 0.454402
# [95]	train's avg_binary_log_loss: 0.447022	valid's avg_binary_log_loss: 0.448508
# [100]	train's avg_binary_log_loss: 0.441464	valid's avg_binary_log_loss: 0.442947
# [105]	train's avg_binary_log_loss: 0.436267	valid's avg_binary_log_loss: 0.437765
# [110]	train's avg_binary_log_loss: 0.431449	valid's avg_binary_log_loss: 0.432945
# [115]	train's avg_binary_log_loss: 0.426954	valid's avg_binary_log_loss: 0.42846
# [120]	train's avg_binary_log_loss: 0.422774	valid's avg_binary_log_loss: 0.424304
# [125]	train's avg_binary_log_loss: 0.418787	valid's avg_binary_log_loss: 0.420337
# [130]	train's avg_binary_log_loss: 0.415019	valid's avg_binary_log_loss: 0.416587
# [135]	train's avg_binary_log_loss: 0.411478	valid's avg_binary_log_loss: 0.413043
# [140]	train's avg_binary_log_loss: 0.408159	valid's avg_binary_log_loss: 0.409719
# [145]	train's avg_binary_log_loss: 0.405059	valid's avg_binary_log_loss: 0.406637
# [150]	train's avg_binary_log_loss: 0.402148	valid's avg_binary_log_loss: 0.403749
# [155]	train's avg_binary_log_loss: 0.399427	valid's avg_binary_log_loss: 0.401037
# [160]	train's avg_binary_log_loss: 0.396851	valid's avg_binary_log_loss: 0.398467
# [165]	train's avg_binary_log_loss: 0.394395	valid's avg_binary_log_loss: 0.396035
# [170]	train's avg_binary_log_loss: 0.392085	valid's avg_binary_log_loss: 0.393722
# [175]	train's avg_binary_log_loss: 0.389918	valid's avg_binary_log_loss: 0.39157
# [180]	train's avg_binary_log_loss: 0.387916	valid's avg_binary_log_loss: 0.38958
# [185]	train's avg_binary_log_loss: 0.386033	valid's avg_binary_log_loss: 0.387742
# [190]	train's avg_binary_log_loss: 0.384237	valid's avg_binary_log_loss: 0.385993
# [195]	train's avg_binary_log_loss: 0.382548	valid's avg_binary_log_loss: 0.384354
# [200]	train's avg_binary_log_loss: 0.380945	valid's avg_binary_log_loss: 0.382803
# [205]	train's avg_binary_log_loss: 0.379444	valid's avg_binary_log_loss: 0.381353
# [210]	train's avg_binary_log_loss: 0.377998	valid's avg_binary_log_loss: 0.379975
# [215]	train's avg_binary_log_loss: 0.376657	valid's avg_binary_log_loss: 0.378717
# [220]	train's avg_binary_log_loss: 0.375407	valid's avg_binary_log_loss: 0.377569
# [225]	train's avg_binary_log_loss: 0.374198	valid's avg_binary_log_loss: 0.376437
# [230]	train's avg_binary_log_loss: 0.373031	valid's avg_binary_log_loss: 0.375345
# [235]	train's avg_binary_log_loss: 0.371901	valid's avg_binary_log_loss: 0.374302
# [240]	train's avg_binary_log_loss: 0.37078	valid's avg_binary_log_loss: 0.373231
# [245]	train's avg_binary_log_loss: 0.369773	valid's avg_binary_log_loss: 0.37228
# [250]	train's avg_binary_log_loss: 0.368764	valid's avg_binary_log_loss: 0.371324
# [255]	train's avg_binary_log_loss: 0.36781	valid's avg_binary_log_loss: 0.370417
# [260]	train's avg_binary_log_loss: 0.366807	valid's avg_binary_log_loss: 0.369455
# [265]	train's avg_binary_log_loss: 0.365922	valid's avg_binary_log_loss: 0.36865
# [270]	train's avg_binary_log_loss: 0.365111	valid's avg_binary_log_loss: 0.367913
# [275]	train's avg_binary_log_loss: 0.364374	valid's avg_binary_log_loss: 0.367221
# [280]	train's avg_binary_log_loss: 0.363668	valid's avg_binary_log_loss: 0.366545
# [285]	train's avg_binary_log_loss: 0.36288	valid's avg_binary_log_loss: 0.365817
# [290]	train's avg_binary_log_loss: 0.362102	valid's avg_binary_log_loss: 0.365071
# [295]	train's avg_binary_log_loss: 0.361413	valid's avg_binary_log_loss: 0.364441
# [300]	train's avg_binary_log_loss: 0.360762	valid's avg_binary_log_loss: 0.363856
# [305]	train's avg_binary_log_loss: 0.360105	valid's avg_binary_log_loss: 0.363266
# [310]	train's avg_binary_log_loss: 0.359507	valid's avg_binary_log_loss: 0.362739
# [315]	train's avg_binary_log_loss: 0.358921	valid's avg_binary_log_loss: 0.362232
# [320]	train's avg_binary_log_loss: 0.358316	valid's avg_binary_log_loss: 0.361665
# [325]	train's avg_binary_log_loss: 0.357759	valid's avg_binary_log_loss: 0.361163
# [330]	train's avg_binary_log_loss: 0.357208	valid's avg_binary_log_loss: 0.36068
# [335]	train's avg_binary_log_loss: 0.356675	valid's avg_binary_log_loss: 0.360208
# [340]	train's avg_binary_log_loss: 0.356215	valid's avg_binary_log_loss: 0.359835
# [345]	train's avg_binary_log_loss: 0.355697	valid's avg_binary_log_loss: 0.359415
# [350]	train's avg_binary_log_loss: 0.3552	valid's avg_binary_log_loss: 0.358992
# [355]	train's avg_binary_log_loss: 0.354762	valid's avg_binary_log_loss: 0.358638
# [360]	train's avg_binary_log_loss: 0.35434	valid's avg_binary_log_loss: 0.358288
# [365]	train's avg_binary_log_loss: 0.353952	valid's avg_binary_log_loss: 0.357986
# [370]	train's avg_binary_log_loss: 0.353588	valid's avg_binary_log_loss: 0.35772
# [375]	train's avg_binary_log_loss: 0.353215	valid's avg_binary_log_loss: 0.357444
# [380]	train's avg_binary_log_loss: 0.352838	valid's avg_binary_log_loss: 0.357151
# [385]	train's avg_binary_log_loss: 0.350762	valid's avg_binary_log_loss: 0.355254
# [390]	train's avg_binary_log_loss: 0.348809	valid's avg_binary_log_loss: 0.353464
# [395]	train's avg_binary_log_loss: 0.346939	valid's avg_binary_log_loss: 0.35177
# [400]	train's avg_binary_log_loss: 0.34654	valid's avg_binary_log_loss: 0.351459
# [405]	train's avg_binary_log_loss: 0.344241	valid's avg_binary_log_loss: 0.349363
# [410]	train's avg_binary_log_loss: 0.342746	valid's avg_binary_log_loss: 0.34802
# [415]	train's avg_binary_log_loss: 0.342375	valid's avg_binary_log_loss: 0.347729
# [420]	train's avg_binary_log_loss: 0.341376	valid's avg_binary_log_loss: 0.346807
# [425]	train's avg_binary_log_loss: 0.338864	valid's avg_binary_log_loss: 0.344503
# [430]	train's avg_binary_log_loss: 0.336825	valid's avg_binary_log_loss: 0.34265
# [435]	train's avg_binary_log_loss: 0.335463	valid's avg_binary_log_loss: 0.341423
# [440]	train's avg_binary_log_loss: 0.334661	valid's avg_binary_log_loss: 0.340741
# [445]	train's avg_binary_log_loss: 0.333892	valid's avg_binary_log_loss: 0.34011
# [450]	train's avg_binary_log_loss: 0.332623	valid's avg_binary_log_loss: 0.338997
# [455]	train's avg_binary_log_loss: 0.331415	valid's avg_binary_log_loss: 0.337933
# [460]	train's avg_binary_log_loss: 0.330253	valid's avg_binary_log_loss: 0.336934
# [465]	train's avg_binary_log_loss: 0.329567	valid's avg_binary_log_loss: 0.336371
# [470]	train's avg_binary_log_loss: 0.328497	valid's avg_binary_log_loss: 0.335415
# [475]	train's avg_binary_log_loss: 0.327437	valid's avg_binary_log_loss: 0.334479
# [480]	train's avg_binary_log_loss: 0.325976	valid's avg_binary_log_loss: 0.333166
# [485]	train's avg_binary_log_loss: 0.324255	valid's avg_binary_log_loss: 0.331618
# [490]	train's avg_binary_log_loss: 0.323689	valid's avg_binary_log_loss: 0.331153
# [495]	train's avg_binary_log_loss: 0.322811	valid's avg_binary_log_loss: 0.330374
# [500]	train's avg_binary_log_loss: 0.322274	valid's avg_binary_log_loss: 0.329954
# [505]	train's avg_binary_log_loss: 0.321433	valid's avg_binary_log_loss: 0.329209
# [510]	train's avg_binary_log_loss: 0.320619	valid's avg_binary_log_loss: 0.328518
# [515]	train's avg_binary_log_loss: 0.31954	valid's avg_binary_log_loss: 0.32758
# [520]	train's avg_binary_log_loss: 0.318774	valid's avg_binary_log_loss: 0.326923
# [525]	train's avg_binary_log_loss: 0.318032	valid's avg_binary_log_loss: 0.326283
# [530]	train's avg_binary_log_loss: 0.317318	valid's avg_binary_log_loss: 0.325687
# [535]	train's avg_binary_log_loss: 0.316623	valid's avg_binary_log_loss: 0.32511
# [540]	train's avg_binary_log_loss: 0.315955	valid's avg_binary_log_loss: 0.324551
# [545]	train's avg_binary_log_loss: 0.315541	valid's avg_binary_log_loss: 0.324248
# [550]	train's avg_binary_log_loss: 0.314894	valid's avg_binary_log_loss: 0.323717
# [555]	train's avg_binary_log_loss: 0.31427	valid's avg_binary_log_loss: 0.323211
# [560]	train's avg_binary_log_loss: 0.313878	valid's avg_binary_log_loss: 0.322933
# [565]	train's avg_binary_log_loss: 0.313496	valid's avg_binary_log_loss: 0.32265
# [570]	train's avg_binary_log_loss: 0.312903	valid's avg_binary_log_loss: 0.322187
# [575]	train's avg_binary_log_loss: 0.312336	valid's avg_binary_log_loss: 0.321725
# [580]	train's avg_binary_log_loss: 0.311971	valid's avg_binary_log_loss: 0.321473
# [585]	train's avg_binary_log_loss: 0.311608	valid's avg_binary_log_loss: 0.321199
# [590]	train's avg_binary_log_loss: 0.311059	valid's avg_binary_log_loss: 0.320784
# [595]	train's avg_binary_log_loss: 0.310525	valid's avg_binary_log_loss: 0.320358
# [600]	train's avg_binary_log_loss: 0.310191	valid's avg_binary_log_loss: 0.320122
# [605]	train's avg_binary_log_loss: 0.309859	valid's avg_binary_log_loss: 0.319868
# [610]	train's avg_binary_log_loss: 0.309367	valid's avg_binary_log_loss: 0.319484
# [615]	train's avg_binary_log_loss: 0.308883	valid's avg_binary_log_loss: 0.319117
# [620]	train's avg_binary_log_loss: 0.30858	valid's avg_binary_log_loss: 0.318904
# [625]	train's avg_binary_log_loss: 0.308283	valid's avg_binary_log_loss: 0.3187
# [630]	train's avg_binary_log_loss: 0.307988	valid's avg_binary_log_loss: 0.318509
# [635]	train's avg_binary_log_loss: 0.307687	valid's avg_binary_log_loss: 0.318305
# [640]	train's avg_binary_log_loss: 0.307234	valid's avg_binary_log_loss: 0.317962
# [645]	train's avg_binary_log_loss: 0.306951	valid's avg_binary_log_loss: 0.317756
# [650]	train's avg_binary_log_loss: 0.306509	valid's avg_binary_log_loss: 0.317429
# [655]	train's avg_binary_log_loss: 0.306083	valid's avg_binary_log_loss: 0.317106
# [660]	train's avg_binary_log_loss: 0.305816	valid's avg_binary_log_loss: 0.316936
# [665]	train's avg_binary_log_loss: 0.305548	valid's avg_binary_log_loss: 0.316757
# [670]	train's avg_binary_log_loss: 0.305176	valid's avg_binary_log_loss: 0.316476
# [675]	train's avg_binary_log_loss: 0.304922	valid's avg_binary_log_loss: 0.316311
# [680]	train's avg_binary_log_loss: 0.304565	valid's avg_binary_log_loss: 0.316034
# [685]	train's avg_binary_log_loss: 0.3041	valid's avg_binary_log_loss: 0.315646
# [690]	train's avg_binary_log_loss: 0.303989	valid's avg_binary_log_loss: 0.315616
# [695]	train's avg_binary_log_loss: 0.303655	valid's avg_binary_log_loss: 0.315362
# [700]	train's avg_binary_log_loss: 0.303325	valid's avg_binary_log_loss: 0.315112
# [705]	train's avg_binary_log_loss: 0.303097	valid's avg_binary_log_loss: 0.31495
# [710]	train's avg_binary_log_loss: 0.302771	valid's avg_binary_log_loss: 0.314707
# [715]	train's avg_binary_log_loss: 0.302449	valid's avg_binary_log_loss: 0.314466
# [720]	train's avg_binary_log_loss: 0.302248	valid's avg_binary_log_loss: 0.314344
# [725]	train's avg_binary_log_loss: 0.301831	valid's avg_binary_log_loss: 0.314015
# [730]	train's avg_binary_log_loss: 0.301531	valid's avg_binary_log_loss: 0.313779
# [735]	train's avg_binary_log_loss: 0.301222	valid's avg_binary_log_loss: 0.313539
# [740]	train's avg_binary_log_loss: 0.300836	valid's avg_binary_log_loss: 0.313228
# [745]	train's avg_binary_log_loss: 0.300547	valid's avg_binary_log_loss: 0.313007
# [750]	train's avg_binary_log_loss: 0.300348	valid's avg_binary_log_loss: 0.312876
# [755]	train's avg_binary_log_loss: 0.300059	valid's avg_binary_log_loss: 0.312641
# [760]	train's avg_binary_log_loss: 0.299793	valid's avg_binary_log_loss: 0.312446
# [765]	train's avg_binary_log_loss: 0.299602	valid's avg_binary_log_loss: 0.312326
# [770]	train's avg_binary_log_loss: 0.299231	valid's avg_binary_log_loss: 0.312018
# [775]	train's avg_binary_log_loss: 0.298881	valid's avg_binary_log_loss: 0.311733
# [780]	train's avg_binary_log_loss: 0.298637	valid's avg_binary_log_loss: 0.311564
# [785]	train's avg_binary_log_loss: 0.298456	valid's avg_binary_log_loss: 0.311464
# [790]	train's avg_binary_log_loss: 0.298123	valid's avg_binary_log_loss: 0.311213
# [795]	train's avg_binary_log_loss: 0.297938	valid's avg_binary_log_loss: 0.311105
# [800]	train's avg_binary_log_loss: 0.297682	valid's avg_binary_log_loss: 0.310915
# [805]	train's avg_binary_log_loss: 0.297497	valid's avg_binary_log_loss: 0.310812
# [810]	train's avg_binary_log_loss: 0.297333	valid's avg_binary_log_loss: 0.310711
# [815]	train's avg_binary_log_loss: 0.29709	valid's avg_binary_log_loss: 0.310524
# [820]	train's avg_binary_log_loss: 0.296848	valid's avg_binary_log_loss: 0.310356
# [825]	train's avg_binary_log_loss: 0.296602	valid's avg_binary_log_loss: 0.310172
# [830]	train's avg_binary_log_loss: 0.296361	valid's avg_binary_log_loss: 0.31001
# [835]	train's avg_binary_log_loss: 0.296189	valid's avg_binary_log_loss: 0.309911
# [840]	train's avg_binary_log_loss: 0.295886	valid's avg_binary_log_loss: 0.30968
# [845]	train's avg_binary_log_loss: 0.295801	valid's avg_binary_log_loss: 0.309661
# [850]	train's avg_binary_log_loss: 0.295713	valid's avg_binary_log_loss: 0.309657
# [855]	train's avg_binary_log_loss: 0.295616	valid's avg_binary_log_loss: 0.309633
# [860]	train's avg_binary_log_loss: 0.295463	valid's avg_binary_log_loss: 0.309553
# [865]	train's avg_binary_log_loss: 0.29537	valid's avg_binary_log_loss: 0.30953
# [870]	train's avg_binary_log_loss: 0.295137	valid's avg_binary_log_loss: 0.309369
# [875]	train's avg_binary_log_loss: 0.294983	valid's avg_binary_log_loss: 0.309285
# [880]	train's avg_binary_log_loss: 0.294825	valid's avg_binary_log_loss: 0.309201
# [885]	train's avg_binary_log_loss: 0.294607	valid's avg_binary_log_loss: 0.30905
# [890]	train's avg_binary_log_loss: 0.294389	valid's avg_binary_log_loss: 0.308908
# [895]	train's avg_binary_log_loss: 0.294173	valid's avg_binary_log_loss: 0.308763
# [900]	train's avg_binary_log_loss: 0.294028	valid's avg_binary_log_loss: 0.30868
# [905]	train's avg_binary_log_loss: 0.293756	valid's avg_binary_log_loss: 0.30849
# ...
# [95]	train's avg_binary_log_loss: 0.285549	valid's avg_binary_log_loss: 0.306007
# [100]	train's avg_binary_log_loss: 0.284177	valid's avg_binary_log_loss: 0.305413
# [105]	train's avg_binary_log_loss: 0.282866	valid's avg_binary_log_loss: 0.305064
# [110]	train's avg_binary_log_loss: 0.282075	valid's avg_binary_log_loss: 0.304896
# [115]	train's avg_binary_log_loss: 0.28087	valid's avg_binary_log_loss: 0.30462
# [120]	train's avg_binary_log_loss: 0.278971	valid's avg_binary_log_loss: 0.303483
# [125]	train's avg_binary_log_loss: 0.277829	valid's avg_binary_log_loss: 0.303116
# [130]	train's avg_binary_log_loss: 0.276993	valid's avg_binary_log_loss: 0.303026
# [135]	train's avg_binary_log_loss: 0.276267	valid's avg_binary_log_loss: 0.303014
# [140]	train's avg_binary_log_loss: 0.275471	valid's avg_binary_log_loss: 0.302886
# [145]	train's avg_binary_log_loss: 0.274781	valid's avg_binary_log_loss: 0.302917
# [150]	train's avg_binary_log_loss: 0.273425	valid's avg_binary_log_loss: 0.302326
# [155]	train's avg_binary_log_loss: 0.272427	valid's avg_binary_log_loss: 0.301917
# [160]	train's avg_binary_log_loss: 0.271469	valid's avg_binary_log_loss: 0.301627
# [165]	train's avg_binary_log_loss: 0.270841	valid's avg_binary_log_loss: 0.301719
# [170]	train's avg_binary_log_loss: 0.269988	valid's avg_binary_log_loss: 0.301506
# [175]	train's avg_binary_log_loss: 0.269063	valid's avg_binary_log_loss: 0.301245
# [180]	train's avg_binary_log_loss: 0.268467	valid's avg_binary_log_loss: 0.301302
# [185]	train's avg_binary_log_loss: 0.267582	valid's avg_binary_log_loss: 0.301346
# [190]	train's avg_binary_log_loss: 0.267021	valid's avg_binary_log_loss: 0.301372
# [195]	train's avg_binary_log_loss: 0.266505	valid's avg_binary_log_loss: 0.301242
# [200]	train's avg_binary_log_loss: 0.26596	valid's avg_binary_log_loss: 0.301243
# [205]	train's avg_binary_log_loss: 0.26495	valid's avg_binary_log_loss: 0.300969
# [210]	train's avg_binary_log_loss: 0.264424	valid's avg_binary_log_loss: 0.300987
# [215]	train's avg_binary_log_loss: 0.263949	valid's avg_binary_log_loss: 0.301245
# [220]	train's avg_binary_log_loss: 0.263209	valid's avg_binary_log_loss: 0.301125
# [225]	train's avg_binary_log_loss: 0.262777	valid's avg_binary_log_loss: 0.301116
# [230]	train's avg_binary_log_loss: 0.262345	valid's avg_binary_log_loss: 0.301091
# [235]	train's avg_binary_log_loss: 0.261497	valid's avg_binary_log_loss: 0.300812
# [240]	train's avg_binary_log_loss: 0.260747	valid's avg_binary_log_loss: 0.30067
# [245]	train's avg_binary_log_loss: 0.259793	valid's avg_binary_log_loss: 0.300496
# [250]	train's avg_binary_log_loss: 0.259403	valid's avg_binary_log_loss: 0.300614
# [255]	train's avg_binary_log_loss: 0.258983	valid's avg_binary_log_loss: 0.300803
# [260]	train's avg_binary_log_loss: 0.258388	valid's avg_binary_log_loss: 0.300687
# [265]	train's avg_binary_log_loss: 0.257957	valid's avg_binary_log_loss: 0.300805
# [270]	train's avg_binary_log_loss: 0.257586	valid's avg_binary_log_loss: 0.300808
# [275]	train's avg_binary_log_loss: 0.25714	valid's avg_binary_log_loss: 0.300897
# [280]	train's avg_binary_log_loss: 0.256695	valid's avg_binary_log_loss: 0.300887
# [285]	train's avg_binary_log_loss: 0.256072	valid's avg_binary_log_loss: 0.300805
# [290]	train's avg_binary_log_loss: 0.255693	valid's avg_binary_log_loss: 0.30076
# [295]	train's avg_binary_log_loss: 0.25513	valid's avg_binary_log_loss: 0.300718
# [300]	train's avg_binary_log_loss: 0.254712	valid's avg_binary_log_loss: 0.300904
# [305]	train's avg_binary_log_loss: 0.254279	valid's avg_binary_log_loss: 0.301039
# [310]	train's avg_binary_log_loss: 0.253628	valid's avg_binary_log_loss: 0.300941
# [315]	train's avg_binary_log_loss: 0.253178	valid's avg_binary_log_loss: 0.301004
# [320]	train's avg_binary_log_loss: 0.252779	valid's avg_binary_log_loss: 0.301016
# [325]	train's avg_binary_log_loss: 0.252406	valid's avg_binary_log_loss: 0.301022
# [330]	train's avg_binary_log_loss: 0.252033	valid's avg_binary_log_loss: 0.301042
# [335]	train's avg_binary_log_loss: 0.251644	valid's avg_binary_log_loss: 0.301254
# [340]	train's avg_binary_log_loss: 0.25094	valid's avg_binary_log_loss: 0.30108
# [345]	train's avg_binary_log_loss: 0.250593	valid's avg_binary_log_loss: 0.301082
# [350]	train's avg_binary_log_loss: 0.250093	valid's avg_binary_log_loss: 0.301058
# [355]	train's avg_binary_log_loss: 0.249362	valid's avg_binary_log_loss: 0.300933
# [360]	train's avg_binary_log_loss: 0.248994	valid's avg_binary_log_loss: 0.300962
# [365]	train's avg_binary_log_loss: 0.248453	valid's avg_binary_log_loss: 0.30095
# [370]	train's avg_binary_log_loss: 0.248098	valid's avg_binary_log_loss: 0.301041
# [375]	train's avg_binary_log_loss: 0.247573	valid's avg_binary_log_loss: 0.301106
# [380]	train's avg_binary_log_loss: 0.247225	valid's avg_binary_log_loss: 0.301358
# [385]	train's avg_binary_log_loss: 0.246588	valid's avg_binary_log_loss: 0.301271
# [390]	train's avg_binary_log_loss: 0.246244	valid's avg_binary_log_loss: 0.301289
# [395]	train's avg_binary_log_loss: 0.245897	valid's avg_binary_log_loss: 0.301369
# [400]	train's avg_binary_log_loss: 0.245551	valid's avg_binary_log_loss: 0.301422
# [405]	train's avg_binary_log_loss: 0.245218	valid's avg_binary_log_loss: 0.301505
# [410]	train's avg_binary_log_loss: 0.244901	valid's avg_binary_log_loss: 0.30163
# [415]	train's avg_binary_log_loss: 0.244565	valid's avg_binary_log_loss: 0.301771
# [420]	train's avg_binary_log_loss: 0.244267	valid's avg_binary_log_loss: 0.301832
# [425]	train's avg_binary_log_loss: 0.243947	valid's avg_binary_log_loss: 0.301879
# [430]	train's avg_binary_log_loss: 0.243629	valid's avg_binary_log_loss: 0.301932
# [435]	train's avg_binary_log_loss: 0.2433	valid's avg_binary_log_loss: 0.302096
# [440]	train's avg_binary_log_loss: 0.242848	valid's avg_binary_log_loss: 0.302176
# [445]	train's avg_binary_log_loss: 0.242437	valid's avg_binary_log_loss: 0.302247
# [450]	train's avg_binary_log_loss: 0.242125	valid's avg_binary_log_loss: 0.302394
# [455]	train's avg_binary_log_loss: 0.241818	valid's avg_binary_log_loss: 0.302395
# [460]	train's avg_binary_log_loss: 0.241504	valid's avg_binary_log_loss: 0.302528
# [465]	train's avg_binary_log_loss: 0.241178	valid's avg_binary_log_loss: 0.302629
# [470]	train's avg_binary_log_loss: 0.240871	valid's avg_binary_log_loss: 0.302681
# [475]	train's avg_binary_log_loss: 0.24054	valid's avg_binary_log_loss: 0.302778
# [480]	train's avg_binary_log_loss: 0.240214	valid's avg_binary_log_loss: 0.302943
# [485]	train's avg_binary_log_loss: 0.23987	valid's avg_binary_log_loss: 0.303158
# [490]	train's avg_binary_log_loss: 0.239561	valid's avg_binary_log_loss: 0.303318
# [495]	train's avg_binary_log_loss: 0.239295	valid's avg_binary_log_loss: 0.303425
# [500]	train's avg_binary_log_loss: 0.238975	valid's avg_binary_log_loss: 0.303628
# [505]	train's avg_binary_log_loss: 0.238538	valid's avg_binary_log_loss: 0.303569
# [510]	train's avg_binary_log_loss: 0.238225	valid's avg_binary_log_loss: 0.303791
# [515]	train's avg_binary_log_loss: 0.237979	valid's avg_binary_log_loss: 0.303911
# [520]	train's avg_binary_log_loss: 0.237646	valid's avg_binary_log_loss: 0.303985
# [525]	train's avg_binary_log_loss: 0.237383	valid's avg_binary_log_loss: 0.304069
# [530]	train's avg_binary_log_loss: 0.237117	valid's avg_binary_log_loss: 0.304182
# [535]	train's avg_binary_log_loss: 0.236804	valid's avg_binary_log_loss: 0.304407
# [540]	train's avg_binary_log_loss: 0.236526	valid's avg_binary_log_loss: 0.304448
# [545]	train's avg_binary_log_loss: 0.236084	valid's avg_binary_log_loss: 0.304497
# [550]	train's avg_binary_log_loss: 0.235764	valid's avg_binary_log_loss: 0.304461
# [555]	train's avg_binary_log_loss: 0.235492	valid's avg_binary_log_loss: 0.304649
# [560]	train's avg_binary_log_loss: 0.235226	valid's avg_binary_log_loss: 0.304743
# [565]	train's avg_binary_log_loss: 0.234912	valid's avg_binary_log_loss: 0.30478
# [570]	train's avg_binary_log_loss: 0.23465	valid's avg_binary_log_loss: 0.304868
# [575]	train's avg_binary_log_loss: 0.234387	valid's avg_binary_log_loss: 0.304964
# [580]	train's avg_binary_log_loss: 0.234051	valid's avg_binary_log_loss: 0.304892
# [585]	train's avg_binary_log_loss: 0.233787	valid's avg_binary_log_loss: 0.305097
# [590]	train's avg_binary_log_loss: 0.233532	valid's avg_binary_log_loss: 0.30521
# [595]	train's avg_binary_log_loss: 0.233265	valid's avg_binary_log_loss: 0.305349
# [600]	train's avg_binary_log_loss: 0.232829	valid's avg_binary_log_loss: 0.305297
# [605]	train's avg_binary_log_loss: 0.232602	valid's avg_binary_log_loss: 0.30539
# [610]	train's avg_binary_log_loss: 0.232192	valid's avg_binary_log_loss: 0.30549
# [615]	train's avg_binary_log_loss: 0.231953	valid's avg_binary_log_loss: 0.305656
# [620]	train's avg_binary_log_loss: 0.231591	valid's avg_binary_log_loss: 0.305631
# [625]	train's avg_binary_log_loss: 0.231351	valid's avg_binary_log_loss: 0.305838
# [630]	train's avg_binary_log_loss: 0.231078	valid's avg_binary_log_loss: 0.305997
# [635]	train's avg_binary_log_loss: 0.230864	valid's avg_binary_log_loss: 0.306023
# [640]	train's avg_binary_log_loss: 0.230628	valid's avg_binary_log_loss: 0.306075
# [645]	train's avg_binary_log_loss: 0.230352	valid's avg_binary_log_loss: 0.306191
# [650]	train's avg_binary_log_loss: 0.230099	valid's avg_binary_log_loss: 0.306236
# [655]	train's avg_binary_log_loss: 0.229811	valid's avg_binary_log_loss: 0.306346
# [660]	train's avg_binary_log_loss: 0.229584	valid's avg_binary_log_loss: 0.306488
# [665]	train's avg_binary_log_loss: 0.229325	valid's avg_binary_log_loss: 0.306477
# [670]	train's avg_binary_log_loss: 0.229069	valid's avg_binary_log_loss: 0.306569
# [675]	train's avg_binary_log_loss: 0.228838	valid's avg_binary_log_loss: 0.306656
# [680]	train's avg_binary_log_loss: 0.228605	valid's avg_binary_log_loss: 0.306763
# [685]	train's avg_binary_log_loss: 0.228365	valid's avg_binary_log_loss: 0.306842
# [690]	train's avg_binary_log_loss: 0.22813	valid's avg_binary_log_loss: 0.306931
# [695]	train's avg_binary_log_loss: 0.2279	valid's avg_binary_log_loss: 0.307093
# [700]	train's avg_binary_log_loss: 0.227519	valid's avg_binary_log_loss: 0.307119
# [705]	train's avg_binary_log_loss: 0.227271	valid's avg_binary_log_loss: 0.307275
# [710]	train's avg_binary_log_loss: 0.227059	valid's avg_binary_log_loss: 0.307448
# [715]	train's avg_binary_log_loss: 0.226821	valid's avg_binary_log_loss: 0.307462
# [720]	train's avg_binary_log_loss: 0.226566	valid's avg_binary_log_loss: 0.307462
# [725]	train's avg_binary_log_loss: 0.226322	valid's avg_binary_log_loss: 0.307556
# [730]	train's avg_binary_log_loss: 0.226088	valid's avg_binary_log_loss: 0.30768
# [735]	train's avg_binary_log_loss: 0.225846	valid's avg_binary_log_loss: 0.307733
# [740]	train's avg_binary_log_loss: 0.225611	valid's avg_binary_log_loss: 0.307786
# [745]	train's avg_binary_log_loss: 0.225364	valid's avg_binary_log_loss: 0.307797
# [750]	train's avg_binary_log_loss: 0.225163	valid's avg_binary_log_loss: 0.307873
# [755]	train's avg_binary_log_loss: 0.22492	valid's avg_binary_log_loss: 0.307991
# [760]	train's avg_binary_log_loss: 0.224666	valid's avg_binary_log_loss: 0.308107
# [765]	train's avg_binary_log_loss: 0.224381	valid's avg_binary_log_loss: 0.308194
# [770]	train's avg_binary_log_loss: 0.224065	valid's avg_binary_log_loss: 0.308325
# [775]	train's avg_binary_log_loss: 0.223769	valid's avg_binary_log_loss: 0.308297
# [780]	train's avg_binary_log_loss: 0.223547	valid's avg_binary_log_loss: 0.308392
# [785]	train's avg_binary_log_loss: 0.223345	valid's avg_binary_log_loss: 0.308509
# [790]	train's avg_binary_log_loss: 0.223163	valid's avg_binary_log_loss: 0.308587
# [795]	train's avg_binary_log_loss: 0.222948	valid's avg_binary_log_loss: 0.308666
# [800]	train's avg_binary_log_loss: 0.222731	valid's avg_binary_log_loss: 0.30871
# [805]	train's avg_binary_log_loss: 0.222499	valid's avg_binary_log_loss: 0.308871
# [810]	train's avg_binary_log_loss: 0.2223	valid's avg_binary_log_loss: 0.308979
# [815]	train's avg_binary_log_loss: 0.222065	valid's avg_binary_log_loss: 0.309106
# [820]	train's avg_binary_log_loss: 0.221831	valid's avg_binary_log_loss: 0.309201
# [825]	train's avg_binary_log_loss: 0.221618	valid's avg_binary_log_loss: 0.309276
# [830]	train's avg_binary_log_loss: 0.221367	valid's avg_binary_log_loss: 0.309357
# [835]	train's avg_binary_log_loss: 0.221026	valid's avg_binary_log_loss: 0.309398
# [840]	train's avg_binary_log_loss: 0.22082	valid's avg_binary_log_loss: 0.309414
# [845]	train's avg_binary_log_loss: 0.220502	valid's avg_binary_log_loss: 0.309608
# [850]	train's avg_binary_log_loss: 0.220311	valid's avg_binary_log_loss: 0.309718
# [855]	train's avg_binary_log_loss: 0.220097	valid's avg_binary_log_loss: 0.30989
# [860]	train's avg_binary_log_loss: 0.219884	valid's avg_binary_log_loss: 0.310024
# [865]	train's avg_binary_log_loss: 0.219646	valid's avg_binary_log_loss: 0.310139
# [870]	train's avg_binary_log_loss: 0.21946	valid's avg_binary_log_loss: 0.310225
# [875]	train's avg_binary_log_loss: 0.219155	valid's avg_binary_log_loss: 0.310162
# [880]	train's avg_binary_log_loss: 0.218947	valid's avg_binary_log_loss: 0.310339
# [885]	train's avg_binary_log_loss: 0.218743	valid's avg_binary_log_loss: 0.310465
# [890]	train's avg_binary_log_loss: 0.218542	valid's avg_binary_log_loss: 0.310554
# [895]	train's avg_binary_log_loss: 0.218331	valid's avg_binary_log_loss: 0.310813
# [900]	train's avg_binary_log_loss: 0.218155	valid's avg_binary_log_loss: 0.310925
# [905]	train's avg_binary_log_loss: 0.217825	valid's avg_binary_log_loss: 0.310889
# [910]	train's avg_binary_log_loss: 0.21762	valid's avg_binary_log_loss: 0.310993
# [915]	train's avg_binary_log_loss: 0.217439	valid's avg_binary_log_loss: 0.31103
# [920]	train's avg_binary_log_loss: 0.21713	valid's avg_binary_log_loss: 0.311057
# [925]	train's avg_binary_log_loss: 0.216913	valid's avg_binary_log_loss: 0.311215
# [930]	train's avg_binary_log_loss: 0.216726	valid's avg_binary_log_loss: 0.311218
# [935]	train's avg_binary_log_loss: 0.216538	valid's avg_binary_log_loss: 0.311361
# [940]	train's avg_binary_log_loss: 0.216333	valid's avg_binary_log_loss: 0.311421
# [945]	train's avg_binary_log_loss: 0.216134	valid's avg_binary_log_loss: 0.311524
# [950]	train's avg_binary_log_loss: 0.215922	valid's avg_binary_log_loss: 0.311636
# [955]	train's avg_binary_log_loss: 0.215702	valid's avg_binary_log_loss: 0.311738
# [960]	train's avg_binary_log_loss: 0.215515	valid's avg_binary_log_loss: 0.311809
# [965]	train's avg_binary_log_loss: 0.215327	valid's avg_binary_log_loss: 0.31177
# [970]	train's avg_binary_log_loss: 0.215138	valid's avg_binary_log_loss: 0.311867
# [975]	train's avg_binary_log_loss: 0.214933	valid's avg_binary_log_loss: 0.312034
# [980]	train's avg_binary_log_loss: 0.21474	valid's avg_binary_log_loss: 0.312069
# [985]	train's avg_binary_log_loss: 0.214601	valid's avg_binary_log_loss: 0.312122
# [990]	train's avg_binary_log_loss: 0.214437	valid's avg_binary_log_loss: 0.312149
# [995]	train's avg_binary_log_loss: 0.214258	valid's avg_binary_log_loss: 0.312301
# [1000]	train's avg_binary_log_loss: 0.214074	valid's avg_binary_log_loss: 0.312428
# Model saved to ../out/models/std_gbdt_census_T1000_S0100_L8_R903.model
# Check valid score: ('avg_binary_log_loss', 0.29151116965925106, False)
#     num_trees  learning_rate  num_leaves  best_round  avg_binary_log_loss
# 0      1000.0           0.01         8.0      1000.0             0.317830
# 1      1000.0           0.01        16.0      1000.0             0.307697
# 2      1000.0           0.01        24.0      1000.0             0.306340
# 3      1000.0           0.01        32.0       999.0             0.306409
# 4      1000.0           0.05         8.0       982.0             0.292053
# 5      1000.0           0.05        16.0       898.0             0.294445
# 6      1000.0           0.05        24.0       659.0             0.298132
# 7      1000.0           0.05        32.0       619.0             0.301114
# 8      1000.0           0.10         8.0       903.0             0.291152
# 9      1000.0           0.10        16.0       394.0             0.295525
# 10     1000.0           0.10        24.0       234.0             0.298616
# 11     1000.0           0.10        32.0       245.0             0.300496
